# %% [markdown]
# <a href="https://colab.research.google.com/github/AjiteshMahalingam/GoGrammar_Writing_Aid/blob/main/GoGrammar_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.6.2-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 7.8 MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.6.2

# %%
pip install gingerit
# Out:
# Collecting gingerit
#   Downloading gingerit-0.8.2-py3-none-any.whl (3.3 kB)
# Collecting requests<3.0.0,>=2.25.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 920 kB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (1.24.3)
# Installing collected packages: requests, gingerit
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed gingerit-0.8.2 requests-2.26.0

# %%
from gingerit.gingerit import GingerIt
from spellchecker import SpellChecker

# %% [markdown]
# ## Construction of English Grammar
#
# Input : English Grammar specifications file
#
# Output : Grammar object
#
# -> English Grammar string processing
#
# -> Construction of Grammar class

# %%
# READING GRAMMAR SPECIFICATIONS

inputFile = open('grammar.txt', 'r')
inputText = inputFile.read()
grammarRules = [ rule.strip() for rule in inputText.split("\n")]
grammarRules
# Out:
# ['S -> NP_SG PAST S1 | NP_SG PAST_PERFECT S1 | NP_SG PAST_CONT_SG S1 | NP_SG PAST_PERFECT_CONT S1 | NP_SG PRES_SG S1 | NP_SG PRES_PERFECT_SG S1 | NP_SG PRES_CONT_SG S1 | NP_SG PRES_PERFECT_CONT_SG S1 | NP_SG FUTURE S1 | NP_SG FUTURE_PERFECT S1 | NP_SG FUTURE_CONT S1 | NP_SG FUTURE_PERFECT_CONT S1 | NP_PL PAST S1 | NP_PL PAST_PERFECT S1 | NP_PL PAST_CONT_PL S1 | NP_PL PAST_PERFECT_CONT S1 | NP_PL PRES_PL S1  | NP_PL PRES_PERFECT_PL S1 | NP_PL PRES_CONT_PL S1 | NP_PL PRES_PERFECT_CONT_PL S1 | NP_PL FUTURE S1 | NP_PL FUTURE_PERFECT S1 | NP_PL FUTURE_CONT S1 | NP_PL FUTURE_PERFECT_CONT S1 | S ADV',
#  'S1 -> NP | ADV',
#  'NP -> NP_SG | NP_PL | PP | NP PP',
#  'NP_SG ->  PRONOUN_SG | PRONOUN_SG NOM_SG| PROPERNOUN | NOM_SG | DET_SG NOM_SG | DET_BOTH NOM_SG | ADV NP_SG | NP_SG CONJ NP',
#  'NOM_SG -> NOUN_SG | ADJ NOUN_SG | NOM_SG NOUN_SG',
#  'NP_PL -> PRONOUN_PL | PRONOUN_PL NOM_PL| NOM_PL | DET_PL NOM_PL | DET_BOTH NOM_PL | ADV NP_PL | NP_PL CONJ NP',
#  'NOM_PL -> NOUN_PL | ADJ NOUN_PL | NOM_PL NOUN_PL',
#  'PP -> PREPOS NP_SG | PREPOS NP_PL',
#  'PAST -> V2 | ADV V2',
#  'PAST_PERFECT -> had V3 | had ADV V3',
#  'PAST_CONT_SG -> was GERUNDV | was ADV GERUNDV',
#  'PAST_CONT_PL -> were GERUNDV | were ADV GERUNDV',
#  'PAST_PERFECT_CONT -> had been GERUNDV | had ADV been GERUNDV',
#  'PRES_SG -> V1_SG | ADV V1_SG',
#  'PRES_PL -> V1_PL | ADV V1_PL',
#  'PRES_PERFECT_SG -> has V3 | has ADV V3',
#  'PRES_PERFECT_PL -> have V3 | have ADV V3',
#  'PRES_CONT_SG -> is GERUNDV | is ADV GERUNDV',
#  'PRES_CONT_PL -> are GERUNDV | are ADV GERUNDV',
#  'PRES_PERFECT_CONT_SG -> has been GERUNDV | has ADV been GERUNDV | has been | has ADV been',
#  'PRES_PERFECT_CONT_PL -> have been GERUNDV | have ADV been GERUNDV',
#  'FUTURE -> will V1_PL | will ADV V1_PL',
#  'FUTURE_PERFECT -> will have V3 | will have ADV V3',
#  'FUTURE_CONT -> will be GERUNDV | will ADV be GERUNDV',
#  'FUTURE_PERFECT_CONT -> will have been GERUNDV | will have ADV been GERUNDV',
#  'PRONOUN_SG -> my | she | he | it | him | i | her | his',
#  'PRONOUN_PL -> they | us | you | we | their',
#  'RELPR_SG -> which',
#  'RELPR_PL -> whom',
#  'PROPERNOUN -> ishwarya | joseph | india | germany | ajitesh | navvya | ritheesh | switzerland | paris | wednesday | january | may | turkey | easter | november | raj | canada | america | john',
#  'NOUN_SG -> sentence | me | kabaddi | friend | patient | parcel | player | moment | morning | grandfather | outlet | evening | programming | building | thinking | mom | weekend | brother | basketball | afternoon | book | accountant | milk | accident | neighbourhood | car | phone | night | airplane | fog | street | dad | bed | fire | house | zoo | cold | pope | cup | sister | party | tea | weather | call | baby | movie | picture | pilot | airport | assignment | week | month | room | homework | husband | year | school | teacher | letter | football | food | mountain | wife | topper | song | show | garden | album',
#  'NOUN_PL -> roses | mountains | goats | films | times | emails | people | children |  specialists | girls | parents | jacksons | cows | boys | books | years | portraits | friends | ages | weeks | letters | peacocks | books',
#  'DET_SG -> a | an | this | that',
#  'DET_PL -> these | all | many | no',
#  'DET_BOTH -> the',
#  'CONJ -> and | but | because | while',
#  'ADJ -> red | delicious | first | few | two | four | three | fun | since | sweet | nice | severe | terrible | hungry | new | whole | last | every | critical',
#  'ADV -> well | gracefully | before | next | very | when | not | whereabouts | constantly | lately | yesterday | ago | tomorrow | early | still | twice | always | already | past | never | today | never | recently | heavily',
#  'PREPOS -> at | in | of | for | by | from | far | on | around | as | to | down',
#  'V1_SG -> climbs | teaches | plays | cooks | is | likes | be | know | am | draws | works | understands | invloves | sings',
#  'V1_PL -> teach | are | sing | give | think | rain | turn | go | see | do | take | study | speak | drink | cook',
#  'GERUNDV -> teaching | running | writing | opening | burning | feeling | enjoying | living | spending | ringing | repairing | visiting | having | climbing | getting | meeting | playing | cleaning | going | looking | suffering | raining | waiting | studying | snowing | seeing | dating | taking | listening | dancing',
#  'V2 -> taught | were | was | went | knew | would | started | received | gave | caught | married | understood | flew | drink | read | made | tired | saw | did',
#  'V3 -> seen | written | given | done | gone | made | flown | painted | fed | met | finished | acted | watched']

# %%
class Grammar :
  def __init__(self, grammarStr) :
    self.input = grammarStr
    self.symbols = set()
    self.terminals = set()
    self.nonterminals = set()
    self.startSymbol = None
    self.grammar = {}

    for production in grammarStr :
      # The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
      head, _, bodies = production.partition(' -> ')
      
      # The nonterminal of the first production is considered to be the start symbol
      if self.startSymbol is None :
        self.startSymbol = head

      self.grammar.setdefault(head, set())
      self.nonterminals.add(head)

      bodies = {tuple(body.strip().split(" ")) for body in ' '.join(bodies.split(" ")).split('|') }

      for body in bodies :
        self.grammar[head].add(body)
        for symbol in body :
          if symbol.isupper() :
            self.nonterminals.add(symbol)
          else :
            self.terminals.add(symbol)  
    
    self.symbols = self.nonterminals | self.terminals

  def __str__ (self) :
    print("Start Symbol : " , self.startSymbol)
    print("Non-terminals : " , self.nonterminals)
    print("Terminals : " , self.terminals)
    print("Productions : ")
    for head in self.grammar :
      for body in self.grammar[head] :
        print(head, "->", body)
    return ""

# %%
G = Grammar(grammarRules)
print(G)
properNouns = set()
for pn in G.grammar["PROPERNOUN"]:
  for noun in pn :
    properNouns.add(noun)
# Out:
# Start Symbol :  S
# Non-terminals :  {'V2', 'PRES_PERFECT_CONT_SG', 'PRES_PERFECT_PL', 'PAST', 'FUTURE_CONT', 'FUTURE_PERFECT', 'PREPOS', 'FUTURE', 'S1', 'RELPR_SG', 'V1_SG', 'DET_BOTH', 'NP_PL', 'DET_PL', 'GERUNDV', 'RELPR_PL', 'PRES_PERFECT_CONT_PL', 'PAST_CONT_PL', 'PRES_PERFECT_SG', 'S', 'PRONOUN_PL', 'DET_SG', 'NP_SG', 'PRES_CONT_PL', 'NOUN_PL', 'ADV', 'NOM_SG', 'V1_PL', 'NOUN_SG', 'PAST_PERFECT', 'CONJ', 'PAST_PERFECT_CONT', 'PRES_PL', 'NOM_PL', 'V3', 'PRONOUN_SG', 'PRES_SG', 'FUTURE_PERFECT_CONT', 'PROPERNOUN', 'NP', 'ADJ', 'PRES_CONT_SG', 'PP', 'PAST_CONT_SG'}
# Terminals :  {'married', 'acted', 'teaches', 'understands', 'would', 'whereabouts', 'delicious', 'raj', 'raining', 'met', 'children', 'never', 'know', 'patient', 'cook', 'meeting', 'understood', 'drink', 'easter', 'we', 'brother', 'wednesday', 'specialists', 'gave', 'flown', 'very', 'films', 'tomorrow', 'ago', 'invloves', 'repairing', 'neighbourhood', 'think', 'wife', 'topper', 'these', 'am', 'she', 'book', 'homework', 'mom', 'twice', 'see', 'dad', 'were', 'living', 'read', 'in', 'joseph', 'building', 'next', 'their', 'parcel', 'picture', 'weather', 'down', 'draws', 'speak', 'teach', 'enjoying', 'boys', 'weekend', 'may', 'weeks', 'basketball', 'past', 'moment', 'husband', 'sister', 'of', 'new', 'the', 'ajitesh', 'be', 'germany', 'they', 'ritheesh', 'kabaddi', 'milk', 'assignment', 'this', 'rain', 'movie', 'a', 'knew', 'whom', 'player', 'that', 'still', 'cooks', 'went', 'two', 'phone', 'cold', 'you', 'january', 'red', 'listening', 'nice', 'room', 'party', 'getting', 'zoo', 'peacocks', 'cleaning', 'saw', 'india', 'books', 'street', 'at', 'dating', 'portraits', 'mountains', 'baby', 'constantly', 'well', 'from', 'pilot', 'climbing', 'critical', 'recently', 'fire', 'today', 'gracefully', 'pope', 'playing', 'afternoon', 'was', 'have', 'turn', 'teaching', 'waiting', 'programming', 'month', 'has', 'morning', 'goats', 'around', 'year', 'jacksons', 'as', 'started', 'football', 'going', 'his', 'many', 'accountant', 'four', 'written', 'i', 'girls', 'when', 'because', 'before', 'works', 'food', 'ishwarya', 'suffering', 'to', 'did', 'friend', 'thinking', 'it', 'been', 'accident', 'house', 'plays', 'climbs', 'sings', 'go', 'me', 'mountain', 'her', 'painted', 'finished', 'show', 'friends', 'terrible', 'week', 'whole', 'study', 'early', 'far', 'three', 'sing', 'running', 'bed', 'visiting', 'taking', 'received', 'gone', 'night', 'tea', 'all', 'call', 'roses', 'letter', 'ringing', 'fed', 'garden', 'severe', 'few', 'while', 'which', 'november', 'by', 'seeing', 'paris', 'evening', 'fog', 'navvya', 'last', 'is', 'give', 'emails', 'always', 'opening', 'tired', 'turkey', 'outlet', 'done', 'letters', 'airplane', 'taught', 'every', 'heavily', 'cows', 'years', 'take', 'album', 'fun', 'us', 'are', 'canada', 'car', 'but', 'studying', 'grandfather', 'having', 'parents', 'john', 'do', 'for', 'caught', 'cup', 'sweet', 'no', 'seen', 'my', 'feeling', 'people', 'looking', 'watched', 'he', 'teacher', 'an', 'since', 'america', 'not', 'flew', 'yesterday', 'snowing', 'airport', 'burning', 'first', 'and', 'dancing', 'writing', 'hungry', 'song', 'spending', 'ages', 'switzerland', 'school', 'likes', 'will', 'already', 'on', 'made', 'given', 'times', 'lately', 'had', 'him', 'sentence'}
# Productions :
# S -> ('NP_PL', 'PRES_CONT_PL', 'S1')
# S -> ('NP_PL', 'PRES_PL', 'S1')
# S -> ('NP_PL', 'FUTURE_CONT', 'S1')
# S -> ('S', 'ADV')
# S -> ('NP_PL', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_CONT_PL', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_SG', 'FUTURE_CONT', 'S1')
# S -> ('NP_SG', 'PAST_CONT_SG', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_CONT_SG', 'S1')
# S -> ('NP_SG', 'FUTURE', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'FUTURE', 'S1')
# S -> ('NP_SG', 'PAST', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PRES_CONT_SG', 'S1')
# S -> ('NP_SG', 'PRES_SG', 'S1')
# S -> ('NP_PL', 'PAST', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_PL', 'S1')
# S -> ('NP_PL', 'PAST_CONT_PL', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_SG', 'S1')
# S1 -> ('ADV',)
# S1 -> ('NP',)
# NP -> ('NP_SG',)
# NP -> ('PP',)
# NP -> ('NP_PL',)
# NP -> ('NP', 'PP')
# NP_SG -> ('PRONOUN_SG', 'NOM_SG')
# NP_SG -> ('PRONOUN_SG',)
# NP_SG -> ('DET_SG', 'NOM_SG')
# NP_SG -> ('NP_SG', 'CONJ', 'NP')
# NP_SG -> ('ADV', 'NP_SG')
# NP_SG -> ('NOM_SG',)
# NP_SG -> ('PROPERNOUN',)
# NP_SG -> ('DET_BOTH', 'NOM_SG')
# NOM_SG -> ('ADJ', 'NOUN_SG')
# NOM_SG -> ('NOM_SG', 'NOUN_SG')
# NOM_SG -> ('NOUN_SG',)
# NP_PL -> ('NOM_PL',)
# NP_PL -> ('ADV', 'NP_PL')
# NP_PL -> ('PRONOUN_PL',)
# NP_PL -> ('NP_PL', 'CONJ', 'NP')
# NP_PL -> ('DET_PL', 'NOM_PL')
# NP_PL -> ('PRONOUN_PL', 'NOM_PL')
# NP_PL -> ('DET_BOTH', 'NOM_PL')
# NOM_PL -> ('NOM_PL', 'NOUN_PL')
# NOM_PL -> ('ADJ', 'NOUN_PL')
# NOM_PL -> ('NOUN_PL',)
# PP -> ('PREPOS', 'NP_PL')
# PP -> ('PREPOS', 'NP_SG')
# PAST -> ('ADV', 'V2')
# PAST -> ('V2',)
# PAST_PERFECT -> ('had', 'V3')
# PAST_PERFECT -> ('had', 'ADV', 'V3')
# PAST_CONT_SG -> ('was', 'GERUNDV')
# PAST_CONT_SG -> ('was', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'ADV', 'been', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'been', 'GERUNDV')
# PRES_SG -> ('ADV', 'V1_SG')
# PRES_SG -> ('V1_SG',)
# PRES_PL -> ('V1_PL',)
# PRES_PL -> ('ADV', 'V1_PL')
# PRES_PERFECT_SG -> ('has', 'ADV', 'V3')
# PRES_PERFECT_SG -> ('has', 'V3')
# PRES_PERFECT_PL -> ('have', 'ADV', 'V3')
# PRES_PERFECT_PL -> ('have', 'V3')
# PRES_CONT_SG -> ('is', 'ADV', 'GERUNDV')
# PRES_CONT_SG -> ('is', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'ADV', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'ADV', 'been', 'GERUNDV')
# FUTURE -> ('will', 'V1_PL')
# FUTURE -> ('will', 'ADV', 'V1_PL')
# FUTURE_PERFECT -> ('will', 'have', 'V3')
# FUTURE_PERFECT -> ('will', 'have', 'ADV', 'V3')
# FUTURE_CONT -> ('will', 'be', 'GERUNDV')
# FUTURE_CONT -> ('will', 'ADV', 'be', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'ADV', 'been', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'been', 'GERUNDV')
# PRONOUN_SG -> ('i',)
# PRONOUN_SG -> ('his',)
# PRONOUN_SG -> ('him',)
# PRONOUN_SG -> ('it',)
# PRONOUN_SG -> ('my',)
# PRONOUN_SG -> ('she',)
# PRONOUN_SG -> ('he',)
# PRONOUN_SG -> ('her',)
# PRONOUN_PL -> ('they',)
# PRONOUN_PL -> ('we',)
# PRONOUN_PL -> ('their',)
# PRONOUN_PL -> ('you',)
# PRONOUN_PL -> ('us',)
# RELPR_SG -> ('which',)
# RELPR_PL -> ('whom',)
# PROPERNOUN -> ('raj',)
# PROPERNOUN -> ('november',)
# PROPERNOUN -> ('john',)
# PROPERNOUN -> ('india',)
# PROPERNOUN -> ('ishwarya',)
# PROPERNOUN -> ('wednesday',)
# PROPERNOUN -> ('january',)
# PROPERNOUN -> ('paris',)
# PROPERNOUN -> ('joseph',)
# PROPERNOUN -> ('germany',)
# PROPERNOUN -> ('ritheesh',)
# PROPERNOUN -> ('may',)
# PROPERNOUN -> ('america',)
# PROPERNOUN -> ('easter',)
# PROPERNOUN -> ('ajitesh',)
# PROPERNOUN -> ('canada',)
# PROPERNOUN -> ('switzerland',)
# PROPERNOUN -> ('turkey',)
# PROPERNOUN -> ('navvya',)
# NOUN_SG -> ('letter',)
# NOUN_SG -> ('weekend',)
# NOUN_SG -> ('bed',)
# NOUN_SG -> ('pope',)
# NOUN_SG -> ('sentence',)
# NOUN_SG -> ('assignment',)
# NOUN_SG -> ('friend',)
# NOUN_SG -> ('thinking',)
# NOUN_SG -> ('week',)
# NOUN_SG -> ('topper',)
# NOUN_SG -> ('song',)
# NOUN_SG -> ('accountant',)
# NOUN_SG -> ('album',)
# NOUN_SG -> ('mountain',)
# NOUN_SG -> ('dad',)
# NOUN_SG -> ('evening',)
# NOUN_SG -> ('airplane',)
# NOUN_SG -> ('month',)
# NOUN_SG -> ('movie',)
# NOUN_SG -> ('phone',)
# NOUN_SG -> ('zoo',)
# NOUN_SG -> ('cold',)
# NOUN_SG -> ('fire',)
# NOUN_SG -> ('basketball',)
# NOUN_SG -> ('cup',)
# NOUN_SG -> ('garden',)
# NOUN_SG -> ('book',)
# NOUN_SG -> ('homework',)
# NOUN_SG -> ('husband',)
# NOUN_SG -> ('teacher',)
# NOUN_SG -> ('outlet',)
# NOUN_SG -> ('room',)
# NOUN_SG -> ('building',)
# NOUN_SG -> ('school',)
# NOUN_SG -> ('kabaddi',)
# NOUN_SG -> ('patient',)
# NOUN_SG -> ('year',)
# NOUN_SG -> ('show',)
# NOUN_SG -> ('milk',)
# NOUN_SG -> ('parcel',)
# NOUN_SG -> ('pilot',)
# NOUN_SG -> ('football',)
# NOUN_SG -> ('wife',)
# NOUN_SG -> ('mom',)
# NOUN_SG -> ('street',)
# NOUN_SG -> ('me',)
# NOUN_SG -> ('airport',)
# NOUN_SG -> ('picture',)
# NOUN_SG -> ('weather',)
# NOUN_SG -> ('programming',)
# NOUN_SG -> ('morning',)
# NOUN_SG -> ('fog',)
# NOUN_SG -> ('neighbourhood',)
# NOUN_SG -> ('night',)
# NOUN_SG -> ('party',)
# NOUN_SG -> ('tea',)
# NOUN_SG -> ('baby',)
# NOUN_SG -> ('brother',)
# NOUN_SG -> ('food',)
# NOUN_SG -> ('accident',)
# NOUN_SG -> ('car',)
# NOUN_SG -> ('house',)
# NOUN_SG -> ('moment',)
# NOUN_SG -> ('player',)
# NOUN_SG -> ('afternoon',)
# NOUN_SG -> ('sister',)
# NOUN_SG -> ('grandfather',)
# NOUN_SG -> ('call',)
# NOUN_PL -> ('times',)
# NOUN_PL -> ('cows',)
# NOUN_PL -> ('weeks',)
# NOUN_PL -> ('letters',)
# NOUN_PL -> ('friends',)
# NOUN_PL -> ('films',)
# NOUN_PL -> ('mountains',)
# NOUN_PL -> ('goats',)
# NOUN_PL -> ('peacocks',)
# NOUN_PL -> ('ages',)
# NOUN_PL -> ('books',)
# NOUN_PL -> ('girls',)
# NOUN_PL -> ('jacksons',)
# NOUN_PL -> ('boys',)
# NOUN_PL -> ('years',)
# NOUN_PL -> ('emails',)
# NOUN_PL -> ('parents',)
# NOUN_PL -> ('portraits',)
# NOUN_PL -> ('children',)
# NOUN_PL -> ('specialists',)
# NOUN_PL -> ('people',)
# NOUN_PL -> ('roses',)
# DET_SG -> ('an',)
# DET_SG -> ('a',)
# DET_SG -> ('that',)
# DET_SG -> ('this',)
# DET_PL -> ('all',)
# DET_PL -> ('no',)
# DET_PL -> ('many',)
# DET_PL -> ('these',)
# DET_BOTH -> ('the',)
# CONJ -> ('because',)
# CONJ -> ('while',)
# CONJ -> ('but',)
# CONJ -> ('and',)
# ADJ -> ('few',)
# ADJ -> ('terrible',)
# ADJ -> ('fun',)
# ADJ -> ('two',)
# ADJ -> ('last',)
# ADJ -> ('severe',)
# ADJ -> ('since',)
# ADJ -> ('first',)
# ADJ -> ('sweet',)
# ADJ -> ('delicious',)
# ADJ -> ('whole',)
# ADJ -> ('hungry',)
# ADJ -> ('four',)
# ADJ -> ('new',)
# ADJ -> ('critical',)
# ADJ -> ('every',)
# ADJ -> ('red',)
# ADJ -> ('nice',)
# ADJ -> ('three',)
# ADV -> ('very',)
# ADV -> ('not',)
# ADV -> ('always',)
# ADV -> ('recently',)
# ADV -> ('today',)
# ADV -> ('past',)
# ADV -> ('when',)
# ADV -> ('tomorrow',)
# ADV -> ('twice',)
# ADV -> ('never',)
# ADV -> ('whereabouts',)
# ADV -> ('yesterday',)
# ADV -> ('next',)
# ADV -> ('gracefully',)
# ADV -> ('lately',)
# ADV -> ('ago',)
# ADV -> ('constantly',)
# ADV -> ('already',)
# ADV -> ('well',)
# ADV -> ('heavily',)
# ADV -> ('early',)
# ADV -> ('still',)
# ADV -> ('before',)
# PREPOS -> ('of',)
# PREPOS -> ('for',)
# PREPOS -> ('around',)
# PREPOS -> ('by',)
# PREPOS -> ('far',)
# PREPOS -> ('to',)
# PREPOS -> ('at',)
# PREPOS -> ('in',)
# PREPOS -> ('on',)
# PREPOS -> ('from',)
# PREPOS -> ('as',)
# PREPOS -> ('down',)
# V1_SG -> ('draws',)
# V1_SG -> ('works',)
# V1_SG -> ('plays',)
# V1_SG -> ('teaches',)
# V1_SG -> ('climbs',)
# V1_SG -> ('am',)
# V1_SG -> ('understands',)
# V1_SG -> ('sings',)
# V1_SG -> ('is',)
# V1_SG -> ('cooks',)
# V1_SG -> ('likes',)
# V1_SG -> ('invloves',)
# V1_SG -> ('be',)
# V1_SG -> ('know',)
# V1_PL -> ('speak',)
# V1_PL -> ('cook',)
# V1_PL -> ('teach',)
# V1_PL -> ('take',)
# V1_PL -> ('rain',)
# V1_PL -> ('are',)
# V1_PL -> ('study',)
# V1_PL -> ('give',)
# V1_PL -> ('sing',)
# V1_PL -> ('go',)
# V1_PL -> ('see',)
# V1_PL -> ('turn',)
# V1_PL -> ('drink',)
# V1_PL -> ('do',)
# V1_PL -> ('think',)
# GERUNDV -> ('visiting',)
# GERUNDV -> ('teaching',)
# GERUNDV -> ('waiting',)
# GERUNDV -> ('seeing',)
# GERUNDV -> ('living',)
# GERUNDV -> ('feeling',)
# GERUNDV -> ('looking',)
# GERUNDV -> ('suffering',)
# GERUNDV -> ('ringing',)
# GERUNDV -> ('studying',)
# GERUNDV -> ('burning',)
# GERUNDV -> ('playing',)
# GERUNDV -> ('snowing',)
# GERUNDV -> ('meeting',)
# GERUNDV -> ('cleaning',)
# GERUNDV -> ('dancing',)
# GERUNDV -> ('climbing',)
# GERUNDV -> ('writing',)
# GERUNDV -> ('spending',)
# GERUNDV -> ('going',)
# GERUNDV -> ('raining',)
# GERUNDV -> ('dating',)
# GERUNDV -> ('opening',)
# GERUNDV -> ('repairing',)
# GERUNDV -> ('enjoying',)
# GERUNDV -> ('getting',)
# GERUNDV -> ('listening',)
# GERUNDV -> ('running',)
# GERUNDV -> ('taking',)
# GERUNDV -> ('having',)
# V2 -> ('understood',)
# V2 -> ('drink',)
# V2 -> ('caught',)
# V2 -> ('were',)
# V2 -> ('started',)
# V2 -> ('gave',)
# V2 -> ('taught',)
# V2 -> ('would',)
# V2 -> ('went',)
# V2 -> ('read',)
# V2 -> ('saw',)
# V2 -> ('did',)
# V2 -> ('flew',)
# V2 -> ('tired',)
# V2 -> ('made',)
# V2 -> ('married',)
# V2 -> ('knew',)
# V2 -> ('received',)
# V2 -> ('was',)
# V3 -> ('flown',)
# V3 -> ('finished',)
# V3 -> ('acted',)
# V3 -> ('seen',)
# V3 -> ('watched',)
# V3 -> ('fed',)
# V3 -> ('gone',)
# V3 -> ('met',)
# V3 -> ('painted',)
# V3 -> ('written',)
# V3 -> ('done',)
# V3 -> ('given',)
# V3 -> ('made',)

# %% [markdown]
# ## Construction of SLR(1) Parser Table
#
# Input : English Grammar Object
#
# Output : SLR(1) Parsing table
#
#
# -> First and Follow
#
# -> Canonical collection of LR(0) items
#
# -> Building Parser table

# %%
# Generating first and follow sets

def first_follow(G) :
  def union(set1, set2):
    set1len = len(set1)
    set1 |= set2
    return set1len != len(set1)

  # initialising the data structures to store and first and follow values
  first = { symbol: set() for symbol in G.symbols }
  follow = { symbol: set() for symbol in G.symbols }

  for symbol in G.symbols :
    if symbol in G.terminals :
      first[symbol].add(symbol)
  
  follow[G.startSymbol].add('$')

  while True :
    updated = False

    for head, bodies in G.grammar.items() :
      for body in bodies :
        for symbol in body :
          if symbol != '^':
            updated |= union(first[head], first[symbol] - set('^'))
            if '^' not in first[symbol] :
              break
            else :
              updated |= union(first[head], set('^'))
        aux = follow[head]
        for symbol in reversed(body) :
          if symbol == '^':
            continue
          if symbol in follow:
            updated |= union(follow[symbol], aux - set('^'))
          if '^' in first[symbol] :
            aux = aux | first[symbol]
          else :
            aux = first[symbol]
    if not updated:
      return first, follow

# %%
# Construction of LR(0) items

# Computation of set of items constructed from I
# I - set of items for G
def CLOSURE(aug_G, I):
  J = I
  
  while True :
    item_len = len(J)
    for head, bodies in J.copy().items() :
      for body in bodies.copy():
        if '.' in body[:-1]:
          dot_pos = body.index('.')
          symbol_after_dot = body[dot_pos + 1]
          if symbol_after_dot in aug_G.nonterminals :
            for G_body in aug_G.grammar[symbol_after_dot]:
              if G_body == tuple('^'):
                J.setdefault(symbol_after_dot, set()).add(set('.'))
              else :
                J.setdefault(symbol_after_dot, set()).add(('.',) + G_body)
    if item_len == len(J):
      return J

# GOTO(I, X) defined to be the closure of the set of all items [A -> aX.b] such that [A -> a.Xb] is in I
# I - set of items
# X - grammar symbol
def GOTO(aug_G, I, X):
  goto = {}

  for head, bodies in I.items() :
    for body in bodies :
      if '.' in body[:-1]:
        dot_pos = body.index('.')
        if body[dot_pos + 1] == X :
          replaced_dot_body = body[ : dot_pos] + (X, '.') + body[dot_pos + 2: ]
          for C_head, C_bodies in CLOSURE(aug_G, {head: {replaced_dot_body}}).items():
            goto.setdefault(C_head, set()).update(C_bodies)
  
  return goto

# Construction of canonical collection of sets of LR(0) items for G'
def items(aug_G):
  C = [CLOSURE(aug_G, {aug_G.startSymbol : {('.', aug_G.startSymbol[:-1])}})]

  while True:
    item_len = len(C)
    for I in C.copy() :
      for X in aug_G.symbols:
        goto = GOTO(aug_G, I, X)
        if (len(goto) > 0) and goto not in C:
          C.append(goto)
    if item_len == len(C) :
      return C

# %%
# Construction of SLR(1) Parsing table

class SLRParser:
  def __init__(self, G):
    self.aug_G = Grammar([f"{G.startSymbol}' -> {G.startSymbol}"] + G.input)
    self.max_aug_G_len = len(max(self.aug_G.grammar, key=len))

    self.G_indexed = []
    for head, bodies in self.aug_G.grammar.items():
      for body in bodies:
        self.G_indexed.append([head, body])
    
    self.first, self.follow = first_follow(self.aug_G)

    self.C = items(self.aug_G)
    
    self.action = list(self.aug_G.terminals) + ['$']
    self.goto = []
    for nonterminal in self.aug_G.nonterminals :
      if nonterminal != self.aug_G.startSymbol :
        self.goto.append(nonterminal)
    
    self.parse_table_symbols = self.action + self.goto
    self.parse_table = self.construct_table()
  
  def construct_table(self):
    # Step 1 - Construct C
    # Step 2 - parsing actions for state i are determined
    parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

    for i, I in enumerate(self.C) :
      for head, bodies in I.items() :
        for body in bodies :
          if '.' in body[:-1] : # Case 2a
            dot_pos = body.index('.')
            symbol_after_dot = body[dot_pos + 1]

            if symbol_after_dot in self.aug_G.terminals :
              s = f's{self.C.index(GOTO(self.aug_G, I, symbol_after_dot))}'
              if s not in parse_table[i][symbol_after_dot]:
                if 'r' in parse_table[i][symbol_after_dot] :
                  parse_table[i][symbol_after_dot] += '/'
                parse_table[i][symbol_after_dot] += s
          
          elif body[-1] == '.' and head != self.aug_G.startSymbol : # Case 2b
            for j, (G_head, G_body) in enumerate(self.G_indexed) :
              if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                for f in self.follow[head] :
                  if parse_table[i][f] :
                    parse_table[i][f] += '/'
                  parse_table[i][f] += f'r{j}'

                break

          else : # Case 2c
            parse_table[i]['$'] = 'acc'
      
      # Step 3 - Goto transistions for all nonterminals are constructed
      for A in self.aug_G.nonterminals :
        j = GOTO(self.aug_G, I, A)
        if j in self.C :
          parse_table[i][A] = self.C.index(j)

    return parse_table

  def __str__ (self) :
    def fprint(text, variable) :
      print(f'{text:>12}: {", ".join(variable)}')
    def print_line() :
      print(f'+{("-" * width + "+") * (len(list(self.aug_G.symbols) + ["$"]))}')
    def symbols_width(symbols) :
      return (width + 1) * len(symbols) - 1

    print("Augmented Grammar : ")
    for i, (head, body) in enumerate(self.G_indexed):
      print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_aug_G_len}} -> {" ".join(body)}')
    print()
    fprint('TERMINALS', self.aug_G.terminals)
    fprint('NONTERMINALS', self.aug_G.nonterminals)
    fprint('SYMBOLS', self.aug_G.symbols)

    print('\nFIRST:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.first[head])} }}')

    print('\nFOLLOW:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.follow[head])} }}')

    width = max(len(c) for c in {'ACTION'} | self.aug_G.symbols) + 2
    for r in range(len(self.C)):
      max_len = max(len(str(c)) for c in self.parse_table[r].values())

      if width < max_len + 2:
        width = max_len + 2

    print('\nPARSING TABLE:')
    print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
    print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
    print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
    print(f'|{"":^{width}}|', end=' ')

    for symbol in self.parse_table_symbols:
      print(f'{symbol:^{width - 1}}|', end=' ')

    print()
    print_line()

    for r in range(len(self.C)):
      print(f'|{r:^{width}}|', end=' ')

      for c in self.parse_table_symbols:
        print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

      print()

    print_line()
    print()
    return ""

# %%
slr = SLRParser(G)
print(slr)
# Out:
# Augmented Grammar :
#   0:                   S' -> S
#   1:                    S -> NP_PL PRES_CONT_PL S1
#   2:                    S -> NP_PL PRES_PL S1
#   3:                    S -> NP_PL FUTURE_CONT S1
#   4:                    S -> S ADV
#   5:                    S -> NP_PL PAST_PERFECT_CONT S1
#   6:                    S -> NP_PL PRES_PERFECT_CONT_PL S1
#   7:                    S -> NP_PL FUTURE_PERFECT S1
#   8:                    S -> NP_SG FUTURE_PERFECT_CONT S1
#   9:                    S -> NP_SG FUTURE_PERFECT S1
#  10:                    S -> NP_SG FUTURE_CONT S1
#  11:                    S -> NP_SG PAST_CONT_SG S1
#  12:                    S -> NP_SG PAST_PERFECT_CONT S1
#  13:                    S -> NP_SG PRES_PERFECT_CONT_SG S1
#  14:                    S -> NP_SG FUTURE S1
#  15:                    S -> NP_SG PAST_PERFECT S1
#  16:                    S -> NP_PL PAST_PERFECT S1
#  17:                    S -> NP_PL FUTURE S1
#  18:                    S -> NP_SG PAST S1
#  19:                    S -> NP_PL FUTURE_PERFECT_CONT S1
#  20:                    S -> NP_SG PRES_CONT_SG S1
#  21:                    S -> NP_SG PRES_SG S1
#  22:                    S -> NP_PL PAST S1
#  23:                    S -> NP_PL PRES_PERFECT_PL S1
#  24:                    S -> NP_PL PAST_CONT_PL S1
#  25:                    S -> NP_SG PRES_PERFECT_SG S1
#  26:                   S1 -> ADV
#  27:                   S1 -> NP
#  28:                   NP -> NP_SG
#  29:                   NP -> PP
#  30:                   NP -> NP_PL
#  31:                   NP -> NP PP
#  32:                NP_SG -> PRONOUN_SG NOM_SG
#  33:                NP_SG -> PRONOUN_SG
#  34:                NP_SG -> DET_SG NOM_SG
#  35:                NP_SG -> NP_SG CONJ NP
#  36:                NP_SG -> ADV NP_SG
#  37:                NP_SG -> NOM_SG
#  38:                NP_SG -> PROPERNOUN
#  39:                NP_SG -> DET_BOTH NOM_SG
#  40:               NOM_SG -> ADJ NOUN_SG
#  41:               NOM_SG -> NOM_SG NOUN_SG
#  42:               NOM_SG -> NOUN_SG
#  43:                NP_PL -> NOM_PL
#  44:                NP_PL -> ADV NP_PL
#  45:                NP_PL -> PRONOUN_PL
#  46:                NP_PL -> NP_PL CONJ NP
#  47:                NP_PL -> DET_PL NOM_PL
#  48:                NP_PL -> PRONOUN_PL NOM_PL
#  49:                NP_PL -> DET_BOTH NOM_PL
#  50:               NOM_PL -> NOM_PL NOUN_PL
#  51:               NOM_PL -> ADJ NOUN_PL
#  52:               NOM_PL -> NOUN_PL
#  53:                   PP -> PREPOS NP_PL
#  54:                   PP -> PREPOS NP_SG
#  55:                 PAST -> ADV V2
#  56:                 PAST -> V2
#  57:         PAST_PERFECT -> had V3
#  58:         PAST_PERFECT -> had ADV V3
#  59:         PAST_CONT_SG -> was GERUNDV
#  60:         PAST_CONT_SG -> was ADV GERUNDV
#  61:         PAST_CONT_PL -> were ADV GERUNDV
#  62:         PAST_CONT_PL -> were GERUNDV
#  63:    PAST_PERFECT_CONT -> had ADV been GERUNDV
#  64:    PAST_PERFECT_CONT -> had been GERUNDV
#  65:              PRES_SG -> ADV V1_SG
#  66:              PRES_SG -> V1_SG
#  67:              PRES_PL -> V1_PL
#  68:              PRES_PL -> ADV V1_PL
#  69:      PRES_PERFECT_SG -> has ADV V3
#  70:      PRES_PERFECT_SG -> has V3
#  71:      PRES_PERFECT_PL -> have ADV V3
#  72:      PRES_PERFECT_PL -> have V3
#  73:         PRES_CONT_SG -> is ADV GERUNDV
#  74:         PRES_CONT_SG -> is GERUNDV
#  75:         PRES_CONT_PL -> are ADV GERUNDV
#  76:         PRES_CONT_PL -> are GERUNDV
#  77: PRES_PERFECT_CONT_SG -> has been
#  78: PRES_PERFECT_CONT_SG -> has been GERUNDV
#  79: PRES_PERFECT_CONT_SG -> has ADV been
#  80: PRES_PERFECT_CONT_SG -> has ADV been GERUNDV
#  81: PRES_PERFECT_CONT_PL -> have been GERUNDV
#  82: PRES_PERFECT_CONT_PL -> have ADV been GERUNDV
#  83:               FUTURE -> will V1_PL
#  84:               FUTURE -> will ADV V1_PL
#  85:       FUTURE_PERFECT -> will have V3
#  86:       FUTURE_PERFECT -> will have ADV V3
#  87:          FUTURE_CONT -> will be GERUNDV
#  88:          FUTURE_CONT -> will ADV be GERUNDV
#  89:  FUTURE_PERFECT_CONT -> will have ADV been GERUNDV
#  90:  FUTURE_PERFECT_CONT -> will have been GERUNDV
#  91:           PRONOUN_SG -> i
#  92:           PRONOUN_SG -> his
#  93:           PRONOUN_SG -> him
#  94:           PRONOUN_SG -> it
#  95:           PRONOUN_SG -> my
#  96:           PRONOUN_SG -> she
#  97:           PRONOUN_SG -> he
#  98:           PRONOUN_SG -> her
#  99:           PRONOUN_PL -> they
# 100:           PRONOUN_PL -> we
# 101:           PRONOUN_PL -> their
# 102:           PRONOUN_PL -> you
# 103:           PRONOUN_PL -> us
# 104:             RELPR_SG -> which
# 105:             RELPR_PL -> whom
# 106:           PROPERNOUN -> raj
# 107:           PROPERNOUN -> november
# 108:           PROPERNOUN -> john
# 109:           PROPERNOUN -> india
# 110:           PROPERNOUN -> ishwarya
# 111:           PROPERNOUN -> wednesday
# 112:           PROPERNOUN -> january
# 113:           PROPERNOUN -> paris
# 114:           PROPERNOUN -> joseph
# 115:           PROPERNOUN -> germany
# 116:           PROPERNOUN -> ritheesh
# 117:           PROPERNOUN -> may
# 118:           PROPERNOUN -> america
# 119:           PROPERNOUN -> easter
# 120:           PROPERNOUN -> ajitesh
# 121:           PROPERNOUN -> canada
# 122:           PROPERNOUN -> switzerland
# 123:           PROPERNOUN -> turkey
# 124:           PROPERNOUN -> navvya
# 125:              NOUN_SG -> letter
# 126:              NOUN_SG -> weekend
# 127:              NOUN_SG -> bed
# 128:              NOUN_SG -> pope
# 129:              NOUN_SG -> sentence
# 130:              NOUN_SG -> assignment
# 131:              NOUN_SG -> friend
# 132:              NOUN_SG -> thinking
# 133:              NOUN_SG -> week
# 134:              NOUN_SG -> topper
# 135:              NOUN_SG -> song
# 136:              NOUN_SG -> accountant
# 137:              NOUN_SG -> album
# 138:              NOUN_SG -> mountain
# 139:              NOUN_SG -> dad
# 140:              NOUN_SG -> evening
# 141:              NOUN_SG -> airplane
# 142:              NOUN_SG -> month
# 143:              NOUN_SG -> movie
# 144:              NOUN_SG -> phone
# 145:              NOUN_SG -> zoo
# 146:              NOUN_SG -> cold
# 147:              NOUN_SG -> fire
# 148:              NOUN_SG -> basketball
# 149:              NOUN_SG -> cup
# 150:              NOUN_SG -> garden
# 151:              NOUN_SG -> book
# 152:              NOUN_SG -> homework
# 153:              NOUN_SG -> husband
# 154:              NOUN_SG -> teacher
# 155:              NOUN_SG -> outlet
# 156:              NOUN_SG -> room
# 157:              NOUN_SG -> building
# 158:              NOUN_SG -> school
# 159:              NOUN_SG -> kabaddi
# 160:              NOUN_SG -> patient
# 161:              NOUN_SG -> year
# 162:              NOUN_SG -> show
# 163:              NOUN_SG -> milk
# 164:              NOUN_SG -> parcel
# 165:              NOUN_SG -> pilot
# 166:              NOUN_SG -> football
# 167:              NOUN_SG -> wife
# 168:              NOUN_SG -> mom
# 169:              NOUN_SG -> street
# 170:              NOUN_SG -> me
# 171:              NOUN_SG -> airport
# 172:              NOUN_SG -> picture
# 173:              NOUN_SG -> weather
# 174:              NOUN_SG -> programming
# 175:              NOUN_SG -> morning
# 176:              NOUN_SG -> fog
# 177:              NOUN_SG -> neighbourhood
# 178:              NOUN_SG -> night
# 179:              NOUN_SG -> party
# 180:              NOUN_SG -> tea
# 181:              NOUN_SG -> baby
# 182:              NOUN_SG -> brother
# 183:              NOUN_SG -> food
# 184:              NOUN_SG -> accident
# 185:              NOUN_SG -> car
# 186:              NOUN_SG -> house
# 187:              NOUN_SG -> moment
# 188:              NOUN_SG -> player
# 189:              NOUN_SG -> afternoon
# 190:              NOUN_SG -> sister
# 191:              NOUN_SG -> grandfather
# 192:              NOUN_SG -> call
# 193:              NOUN_PL -> times
# 194:              NOUN_PL -> cows
# 195:              NOUN_PL -> weeks
# 196:              NOUN_PL -> letters
# 197:              NOUN_PL -> friends
# 198:              NOUN_PL -> films
# 199:              NOUN_PL -> mountains
# 200:              NOUN_PL -> goats
# 201:              NOUN_PL -> peacocks
# 202:              NOUN_PL -> ages
# 203:              NOUN_PL -> books
# 204:              NOUN_PL -> girls
# 205:              NOUN_PL -> jacksons
# 206:              NOUN_PL -> boys
# 207:              NOUN_PL -> years
# 208:              NOUN_PL -> emails
# 209:              NOUN_PL -> parents
# 210:              NOUN_PL -> portraits
# 211:              NOUN_PL -> children
# 212:              NOUN_PL -> specialists
# 213:              NOUN_PL -> people
# 214:              NOUN_PL -> roses
# 215:               DET_SG -> an
# 216:               DET_SG -> a
# 217:               DET_SG -> that
# 218:               DET_SG -> this
# 219:               DET_PL -> all
# 220:               DET_PL -> no
# 221:               DET_PL -> many
# 222:               DET_PL -> these
# 223:             DET_BOTH -> the
# 224:                 CONJ -> because
# 225:                 CONJ -> while
# 226:                 CONJ -> but
# 227:                 CONJ -> and
# 228:                  ADJ -> few
# 229:                  ADJ -> terrible
# 230:                  ADJ -> fun
# 231:                  ADJ -> two
# 232:                  ADJ -> last
# 233:                  ADJ -> severe
# 234:                  ADJ -> since
# 235:                  ADJ -> first
# 236:                  ADJ -> sweet
# 237:                  ADJ -> delicious
# 238:                  ADJ -> whole
# 239:                  ADJ -> hungry
# 240:                  ADJ -> four
# 241:                  ADJ -> new
# 242:                  ADJ -> critical
# 243:                  ADJ -> every
# 244:                  ADJ -> red
# 245:                  ADJ -> nice
# 246:                  ADJ -> three
# 247:                  ADV -> very
# 248:                  ADV -> not
# 249:                  ADV -> always
# 250:                  ADV -> recently
# 251:                  ADV -> today
# 252:                  ADV -> past
# 253:                  ADV -> when
# 254:                  ADV -> tomorrow
# 255:                  ADV -> twice
# 256:                  ADV -> never
# 257:                  ADV -> whereabouts
# 258:                  ADV -> yesterday
# 259:                  ADV -> next
# 260:                  ADV -> gracefully
# 261:                  ADV -> lately
# 262:                  ADV -> ago
# 263:                  ADV -> constantly
# 264:                  ADV -> already
# 265:                  ADV -> well
# 266:                  ADV -> heavily
# 267:                  ADV -> early
# 268:                  ADV -> still
# 269:                  ADV -> before
# 270:               PREPOS -> of
# 271:               PREPOS -> for
# 272:               PREPOS -> around
# 273:               PREPOS -> by
# 274:               PREPOS -> far
# 275:               PREPOS -> to
# 276:               PREPOS -> at
# 277:               PREPOS -> in
# 278:               PREPOS -> on
# 279:               PREPOS -> from
# 280:               PREPOS -> as
# 281:               PREPOS -> down
# 282:                V1_SG -> draws
# 283:                V1_SG -> works
# 284:                V1_SG -> plays
# 285:                V1_SG -> teaches
# 286:                V1_SG -> climbs
# 287:                V1_SG -> am
# 288:                V1_SG -> understands
# 289:                V1_SG -> sings
# 290:                V1_SG -> is
# 291:                V1_SG -> cooks
# 292:                V1_SG -> likes
# 293:                V1_SG -> invloves
# 294:                V1_SG -> be
# 295:                V1_SG -> know
# 296:                V1_PL -> speak
# 297:                V1_PL -> cook
# 298:                V1_PL -> teach
# 299:                V1_PL -> take
# 300:                V1_PL -> rain
# 301:                V1_PL -> are
# 302:                V1_PL -> study
# 303:                V1_PL -> give
# 304:                V1_PL -> sing
# 305:                V1_PL -> go
# 306:                V1_PL -> see
# 307:                V1_PL -> turn
# 308:                V1_PL -> drink
# 309:                V1_PL -> do
# 310:                V1_PL -> think
# 311:              GERUNDV -> visiting
# 312:              GERUNDV -> teaching
# 313:              GERUNDV -> waiting
# 314:              GERUNDV -> seeing
# 315:              GERUNDV -> living
# 316:              GERUNDV -> feeling
# 317:              GERUNDV -> looking
# 318:              GERUNDV -> suffering
# 319:              GERUNDV -> ringing
# 320:              GERUNDV -> studying
# 321:              GERUNDV -> burning
# 322:              GERUNDV -> playing
# 323:              GERUNDV -> snowing
# 324:              GERUNDV -> meeting
# 325:              GERUNDV -> cleaning
# 326:              GERUNDV -> dancing
# 327:              GERUNDV -> climbing
# 328:              GERUNDV -> writing
# 329:              GERUNDV -> spending
# 330:              GERUNDV -> going
# 331:              GERUNDV -> raining
# 332:              GERUNDV -> dating
# 333:              GERUNDV -> opening
# 334:              GERUNDV -> repairing
# 335:              GERUNDV -> enjoying
# 336:              GERUNDV -> getting
# 337:              GERUNDV -> listening
# 338:              GERUNDV -> running
# 339:              GERUNDV -> taking
# 340:              GERUNDV -> having
# 341:                   V2 -> understood
# 342:                   V2 -> drink
# 343:                   V2 -> caught
# 344:                   V2 -> were
# 345:                   V2 -> started
# 346:                   V2 -> gave
# 347:                   V2 -> taught
# 348:                   V2 -> would
# 349:                   V2 -> went
# 350:                   V2 -> read
# 351:                   V2 -> saw
# 352:                   V2 -> did
# 353:                   V2 -> flew
# 354:                   V2 -> tired
# 355:                   V2 -> made
# 356:                   V2 -> married
# 357:                   V2 -> knew
# 358:                   V2 -> received
# 359:                   V2 -> was
# 360:                   V3 -> flown
# 361:                   V3 -> finished
# 362:                   V3 -> acted
# 363:                   V3 -> seen
# 364:                   V3 -> watched
# 365:                   V3 -> fed
# 366:                   V3 -> gone
# 367:                   V3 -> met
# 368:                   V3 -> painted
# 369:                   V3 -> written
# 370:                   V3 -> done
# 371:                   V3 -> given
# 372:                   V3 -> made
#
#    TERMINALS: married, acted, teaches, understands, would, whereabouts, delicious, raj, raining, met, children, never, know, patient, cook, meeting, understood, drink, easter, we, brother, wednesday, specialists, gave, flown, very, films, tomorrow, ago, invloves, repairing, neighbourhood, think, wife, topper, these, am, she, book, homework, mom, twice, see, dad, were, living, read, in, joseph, building, next, their, parcel, picture, weather, down, draws, speak, teach, enjoying, boys, weekend, may, weeks, basketball, past, moment, husband, sister, of, new, the, ajitesh, be, germany, they, ritheesh, kabaddi, milk, assignment, this, rain, movie, a, knew, whom, player, that, still, cooks, went, two, phone, cold, you, january, red, listening, nice, room, party, getting, zoo, peacocks, cleaning, saw, india, books, street, at, dating, portraits, mountains, baby, constantly, well, from, pilot, climbing, critical, recently, fire, today, gracefully, pope, playing, afternoon, was, have, turn, teaching, waiting, programming, month, has, morning, goats, around, year, jacksons, as, started, football, going, his, many, accountant, four, written, i, girls, when, because, before, works, food, ishwarya, suffering, to, did, friend, thinking, it, been, accident, house, plays, climbs, sings, go, me, mountain, her, painted, finished, show, friends, terrible, week, whole, study, early, far, three, sing, running, bed, visiting, taking, received, gone, night, tea, all, call, roses, letter, ringing, fed, garden, severe, few, while, which, november, by, seeing, paris, evening, fog, navvya, last, is, give, emails, always, opening, tired, turkey, outlet, done, letters, airplane, taught, every, heavily, cows, years, take, album, fun, us, are, canada, car, but, studying, grandfather, having, parents, john, do, for, caught, cup, sweet, no, seen, my, feeling, people, looking, watched, he, teacher, an, since, america, not, flew, yesterday, snowing, airport, burning, first, and, dancing, writing, hungry, song, spending, ages, switzerland, school, likes, will, already, on, made, given, times, lately, had, him, sentence
# NONTERMINALS: V2, PRES_PERFECT_CONT_SG, PRES_PERFECT_PL, PAST, FUTURE_CONT, FUTURE_PERFECT, PREPOS, FUTURE, S1, RELPR_SG, V1_SG, DET_BOTH, NP_PL, DET_PL, GERUNDV, RELPR_PL, PRES_PERFECT_CONT_PL, PAST_CONT_PL, PRES_PERFECT_SG, S, PRONOUN_PL, DET_SG, NP_SG, PRES_CONT_PL, NOUN_PL, ADV, NOM_SG, V1_PL, NOUN_SG, PAST_PERFECT, CONJ, PAST_PERFECT_CONT, PRES_PL, NOM_PL, V3, PRONOUN_SG, PRES_SG, FUTURE_PERFECT_CONT, PROPERNOUN, NP, ADJ, PRES_CONT_SG, PP, PAST_CONT_SG, S'
#      SYMBOLS: married, acted, understands, FUTURE_CONT, would, delicious, met, understood, we, brother, specialists, flown, films, NP_PL, DET_PL, ago, invloves, repairing, PRONOUN_PL, topper, these, book, homework, dad, read, building, next, down, speak, parcel, weather, enjoying, PRES_PL, teach, boys, PROPERNOUN, sister, of, PP, new, think, germany, kabaddi, ritheesh, this, rain, that, still, january, room, zoo, cleaning, books, street, dating, well, PAST_PERFECT_CONT, critical, recently, gracefully, FUTURE_PERFECT_CONT, afternoon, was, have, turn, teaching, waiting, morning, started, has, goats, year, jacksons, as, his, FUTURE_PERFECT, written, when, because, works, food, suffering, to, DET_BOTH, friend, accident, house, RELPR_PL, plays, painted, taught, PRES_PERFECT_CONT_PL, me, her, show, terrible, early, running, visiting, night, letter, fed, garden, severe, which, november, seeing, evening, fog, last, is, emails, always, tired, outlet, RELPR_SG, V1_SG, take, album, fun, canada, car, but, studying, having, parents, PAST_CONT_PL, john, caught, sweet, NOUN_PL, seen, looking, NOM_SG, he, teacher, flew, not, yesterday, airport, burning, first, and, dancing, ages, switzerland, ADJ, will, already, on, PAST_CONT_SG, him, sentence, teaches, PAST, whereabouts, raining, raj, children, never, know, patient, cook, meeting, drink, easter, wednesday, gave, very, GERUNDV, tomorrow, neighbourhood, DET_SG, wife, ADV, am, she, twice, see, mom, V1_PL, were, living, in, joseph, their, picture, NOM_PL, draws, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, be, they, milk, assignment, movie, a, knew, whom, player, cooks, went, two, phone, cold, you, red, listening, nice, party, getting, S, peacocks, saw, PRES_CONT_PL, india, at, portraits, mountains, baby, constantly, from, PAST_PERFECT, pilot, climbing, fire, today, PRES_SG, pope, playing, NP, PRES_CONT_SG, programming, month, around, football, going, PRES_PERFECT_PL, many, accountant, four, i, PREPOS, girls, before, ishwarya, did, thinking, it, been, climbs, sings, go, mountain, finished, friends, whole, week, study, far, received, three, sing, taking, bed, gone, tea, NOUN_SG, all, call, roses, CONJ, ringing, few, while, by, paris, navvya, V2, PRES_PERFECT_CONT_SG, give, opening, turkey, done, FUTURE, letters, S1, airplane, every, heavily, cows, years, us, are, grandfather, do, for, PRES_PERFECT_SG, cup, no, NP_SG, my, feeling, people, watched, since, an, america, snowing, V3, PRONOUN_SG, writing, spending, hungry, song, school, likes, made, given, S', times, lately, had
#
# FIRST:
#                   S' = { delicious, we, specialists, brother, films, ago, topper, these, book, homework, dad, next, building, parcel, weather, boys, sister, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, jacksons, year, his, when, food, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, joseph, their, picture, weeks, may, weekend, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, constantly, portraits, mountains, baby, pilot, today, fire, pope, programming, month, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, three, bed, tea, all, roses, call, few, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#                    S = { delicious, we, specialists, brother, films, ago, topper, these, book, homework, dad, next, building, parcel, weather, boys, sister, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, jacksons, year, his, when, food, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, joseph, their, picture, weeks, may, weekend, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, constantly, portraits, mountains, baby, pilot, today, fire, pope, programming, month, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, three, bed, tea, all, roses, call, few, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#                   S1 = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#                   NP = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, that, still, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, she, twice, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#                NP_SG = { whereabouts, delicious, raj, never, patient, easter, brother, wednesday, very, tomorrow, ago, neighbourhood, wife, topper, she, twice, book, homework, mom, dad, next, joseph, building, parcel, picture, weather, weekend, may, basketball, past, moment, husband, sister, new, the, ajitesh, germany, kabaddi, ritheesh, this, milk, assignment, movie, a, that, still, player, two, phone, cold, january, red, nice, room, party, zoo, india, street, constantly, well, baby, pilot, critical, recently, today, fire, gracefully, pope, afternoon, programming, month, morning, year, football, his, accountant, four, i, when, before, food, ishwarya, friend, thinking, it, accident, house, me, mountain, her, show, terrible, whole, week, early, three, bed, night, tea, call, letter, severe, garden, few, november, paris, evening, fog, navvya, last, always, turkey, outlet, airplane, heavily, every, album, fun, canada, car, grandfather, john, cup, sweet, my, he, an, since, teacher, america, not, yesterday, airport, first, hungry, song, switzerland, school, already, lately, him, sentence }
#               NOM_SG = { delicious, patient, brother, neighbourhood, wife, topper, book, homework, mom, dad, building, parcel, picture, weather, weekend, basketball, moment, husband, sister, new, kabaddi, milk, assignment, movie, player, two, phone, cold, red, nice, room, party, zoo, street, baby, pilot, critical, fire, pope, afternoon, programming, month, morning, year, football, accountant, four, food, friend, thinking, accident, house, me, mountain, show, terrible, whole, week, three, bed, night, tea, call, letter, severe, garden, few, evening, fog, last, outlet, airplane, every, album, fun, car, grandfather, cup, sweet, since, teacher, airport, first, hungry, song, school, sentence }
#                NP_PL = { many, whereabouts, delicious, four, children, when, never, girls, before, we, specialists, very, films, tomorrow, ago, terrible, whole, friends, early, these, three, twice, all, next, roses, their, severe, boys, few, weeks, past, new, the, they, last, still, emails, always, letters, two, heavily, you, every, cows, years, fun, us, red, nice, parents, peacocks, sweet, no, people, books, since, not, constantly, portraits, well, mountains, yesterday, critical, recently, today, gracefully, first, hungry, ages, already, goats, jacksons, times, lately }
#               NOM_PL = { delicious, four, children, girls, specialists, films, terrible, whole, friends, three, roses, severe, boys, few, weeks, new, last, emails, letters, two, every, cows, years, fun, red, nice, parents, peacocks, sweet, people, books, since, portraits, mountains, critical, first, hungry, ages, goats, jacksons, times }
#                   PP = { far, at, from, in, down, to, by, of, on, for, around, as }
#                 PAST = { married, knew, would, still, whereabouts, tired, always, when, never, went, before, understood, drink, gave, heavily, very, did, taught, tomorrow, ago, caught, saw, early, received, twice, flew, not, constantly, were, well, read, yesterday, next, recently, today, gracefully, past, was, already, started, made, lately }
#         PAST_PERFECT = { had }
#         PAST_CONT_SG = { was }
#         PAST_CONT_PL = { were }
#    PAST_PERFECT_CONT = { had }
#              PRES_SG = { teaches, understands, is, still, whereabouts, cooks, always, when, never, before, know, works, heavily, very, plays, climbs, sings, tomorrow, ago, invloves, early, am, twice, not, constantly, well, yesterday, next, recently, draws, today, gracefully, past, likes, already, be, lately }
#              PRES_PL = { still, whereabouts, give, always, when, never, before, cook, drink, heavily, take, very, are, go, tomorrow, ago, do, study, early, sing, twice, see, not, constantly, well, yesterday, next, speak, teach, recently, today, gracefully, past, turn, already, think, lately, rain }
#      PRES_PERFECT_SG = { has }
#      PRES_PERFECT_PL = { have }
#         PRES_CONT_SG = { is }
#         PRES_CONT_PL = { are }
# PRES_PERFECT_CONT_SG = { has }
# PRES_PERFECT_CONT_PL = { have }
#               FUTURE = { will }
#       FUTURE_PERFECT = { will }
#          FUTURE_CONT = { will }
#  FUTURE_PERFECT_CONT = { will }
#           PRONOUN_SG = { his, she, he, it, i, her, him, my }
#           PRONOUN_PL = { we, their, us, they, you }
#             RELPR_SG = { which }
#             RELPR_PL = { whom }
#           PROPERNOUN = { india, raj, america, turkey, joseph, easter, ishwarya, wednesday, january, may, november, canada, switzerland, paris, john, ajitesh, navvya, germany, ritheesh }
#              NOUN_SG = { movie, player, accountant, outlet, patient, airplane, brother, phone, cold, food, kabaddi, friend, thinking, album, accident, car, house, room, grandfather, me, mountain, neighbourhood, party, cup, zoo, show, wife, week, topper, book, homework, bed, teacher, mom, street, dad, night, tea, baby, building, call, letter, parcel, pilot, airport, picture, weather, fire, garden, weekend, pope, song, sentence, basketball, moment, husband, afternoon, school, sister, evening, programming, month, morning, fog, year, milk, football, assignment }
#              NOUN_PL = { people, books, emails, portraits, mountains, children, girls, roses, letters, specialists, cows, weeks, boys, years, films, ages, parents, goats, peacocks, jacksons, times, friends }
#               DET_SG = { a, that, an, this }
#               DET_PL = { all, many, these, no }
#             DET_BOTH = { the }
#                 CONJ = { and, while, because, but }
#                  ADJ = { last, three, since, delicious, four, critical, two, every, severe, first, few, hungry, fun, red, nice, new, sweet, terrible, whole }
#                  ADV = { early, twice, whereabouts, still, not, always, constantly, well, when, never, yesterday, next, before, recently, today, heavily, gracefully, very, past, tomorrow, ago, already, lately }
#               PREPOS = { far, by, at, from, of, in, on, down, for, around, as, to }
#                V1_SG = { teaches, am, understands, is, plays, climbs, sings, cooks, likes, invloves, know, works, be, draws }
#                V1_PL = { take, study, sing, see, are, give, go, turn, do, cook, speak, drink, teach, think, rain }
#              GERUNDV = { feeling, looking, running, taking, visiting, raining, dating, opening, living, snowing, meeting, climbing, enjoying, suffering, ringing, burning, dancing, writing, spending, seeing, listening, studying, playing, having, waiting, teaching, repairing, getting, cleaning, going }
#                   V2 = { married, knew, received, would, flew, tired, were, went, read, understood, drink, gave, did, taught, was, caught, started, made, saw }
#                   V3 = { acted, watched, gone, met, painted, written, done, given, made, finished, flown, seen, fed }
#
# FOLLOW:
#                   S' = { $ }
#                    S = { still, whereabouts, always, when, never, before, heavily, very, tomorrow, ago, early, twice, not, constantly, well, yesterday, next, $, recently, today, gracefully, past, already, lately }
#                   S1 = { still, whereabouts, always, when, never, before, heavily, very, tomorrow, ago, early, twice, not, constantly, well, yesterday, next, $, recently, today, gracefully, past, already, lately }
#                   NP = { married, teaches, understands, would, whereabouts, never, know, cook, understood, drink, gave, very, tomorrow, ago, invloves, am, twice, see, were, read, in, next, down, speak, draws, teach, past, of, be, think, rain, knew, still, cooks, went, saw, at, constantly, from, well, recently, today, gracefully, was, have, turn, started, has, around, as, when, before, because, works, to, did, plays, taught, climbs, sings, go, study, early, far, received, sing, $, while, by, is, give, tired, always, heavily, take, are, but, caught, do, for, flew, not, yesterday, and, likes, already, will, on, made, lately, had }
#                NP_SG = { married, teaches, understands, would, whereabouts, never, know, cook, understood, drink, gave, very, tomorrow, ago, invloves, am, twice, see, were, read, in, next, down, speak, draws, teach, past, of, be, think, rain, knew, still, cooks, went, saw, at, constantly, from, well, recently, today, gracefully, was, have, turn, started, has, around, as, when, before, because, works, to, did, plays, taught, climbs, sings, go, study, early, received, far, sing, $, while, by, is, give, tired, always, heavily, take, are, but, caught, do, for, flew, not, yesterday, and, likes, will, already, made, on, lately, had }
#               NOM_SG = { married, teaches, understands, would, whereabouts, never, know, patient, cook, understood, drink, brother, gave, very, tomorrow, ago, invloves, neighbourhood, wife, topper, am, twice, book, homework, mom, see, dad, were, read, in, next, building, down, speak, parcel, picture, weather, draws, teach, weekend, basketball, past, moment, husband, sister, of, be, kabaddi, think, milk, rain, assignment, movie, knew, still, player, cooks, went, phone, cold, room, party, zoo, saw, street, at, constantly, from, well, baby, pilot, recently, today, fire, gracefully, pope, afternoon, was, have, turn, programming, month, has, morning, started, around, year, as, football, accountant, when, before, because, works, food, to, did, friend, thinking, accident, house, plays, taught, climbs, sings, go, me, mountain, show, week, study, early, received, far, sing, bed, night, tea, call, letter, $, garden, while, by, evening, fog, is, give, tired, always, outlet, airplane, heavily, take, album, car, but, are, grandfather, caught, do, for, cup, teacher, flew, not, yesterday, airport, and, song, school, likes, will, already, made, on, lately, had, sentence }
#                NP_PL = { married, teaches, understands, would, whereabouts, never, know, cook, understood, drink, gave, very, tomorrow, ago, invloves, am, twice, see, were, read, in, next, down, speak, teach, draws, past, of, think, be, rain, knew, still, cooks, went, saw, at, constantly, from, well, recently, today, gracefully, turn, have, was, started, has, around, as, when, before, because, works, to, did, plays, taught, climbs, go, sings, study, early, received, sing, far, $, while, by, is, give, tired, always, heavily, take, are, but, do, caught, for, flew, not, yesterday, and, likes, will, already, made, on, lately, had }
#               NOM_PL = { married, teaches, understands, would, whereabouts, children, never, know, cook, understood, drink, specialists, gave, very, films, tomorrow, ago, invloves, am, twice, see, were, read, in, next, down, speak, teach, draws, boys, weeks, past, of, think, be, rain, knew, still, cooks, went, peacocks, saw, books, at, constantly, portraits, well, mountains, from, recently, today, gracefully, turn, have, was, started, has, goats, around, jacksons, as, when, girls, before, because, works, to, did, plays, taught, climbs, go, sings, friends, study, early, received, sing, far, roses, $, while, by, is, give, emails, always, tired, letters, heavily, cows, years, take, are, but, parents, do, caught, for, people, flew, not, yesterday, and, ages, likes, will, already, made, on, times, lately, had }
#                   PP = { married, teaches, understands, would, whereabouts, never, know, cook, understood, drink, gave, very, tomorrow, ago, invloves, am, twice, see, were, read, in, next, down, speak, draws, teach, past, of, be, think, rain, knew, still, cooks, went, saw, at, constantly, from, well, recently, today, gracefully, was, have, turn, started, has, around, as, when, before, because, works, to, did, plays, taught, climbs, sings, go, study, early, far, received, sing, $, while, by, is, give, tired, always, heavily, take, are, but, caught, do, for, flew, not, yesterday, and, likes, already, will, on, made, lately, had }
#                 PAST = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#         PAST_PERFECT = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#         PAST_CONT_SG = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#         PAST_CONT_PL = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#    PAST_PERFECT_CONT = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#              PRES_SG = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#              PRES_PL = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
#      PRES_PERFECT_SG = { delicious, we, brother, specialists, films, ago, topper, these, book, homework, dad, next, down, building, parcel, weather, boys, sister, of, new, germany, kabaddi, ritheesh, this, still, that, january, room, zoo, books, street, well, critical, recently, gracefully, afternoon, morning, goats, as, year, jacksons, his, when, food, to, friend, accident, house, me, her, show, terrible, early, night, letter, severe, garden, november, evening, fog, last, emails, always, outlet, album, fun, canada, car, parents, john, sweet, he, teacher, not, yesterday, airport, first, ages, switzerland, already, on, him, sentence, whereabouts, raj, children, never, patient, easter, wednesday, very, tomorrow, neighbourhood, wife, twice, she, mom, in, joseph, their, picture, weekend, may, weeks, basketball, past, moment, husband, the, ajitesh, they, milk, assignment, movie, a, player, two, phone, cold, you, red, nice, party, peacocks, india, at, constantly, from, baby, portraits, mountains, pilot, today, fire, pope, programming, month, around, football, many, accountant, four, i, girls, before, ishwarya, thinking, it, mountain, friends, whole, week, far, three, bed, tea, all, call, roses, few, by, paris, navvya, turkey, letters, airplane, heavily, every, cows, years, us, grandfather, for, cup, no, my, people, since, an, america, hungry, song, school, times, lately }
# ...
# |         437          |                      |                      |                      |                      |                      |          r80         |          r80         |          r80         |                      |                      |          r80         |          r80         |                      |          r80         |                      |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |          r80         |          r80         |          r80         |          r80         |                      |                      |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |                      |                      |          r80         |          r80         |          r80         |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |          r80         |                      |                      |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |                      |                      |                      |                      |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |          r80         |                      |                      |                      |                      |          r80         |          r80         |          r80        ...
# |         438          |                      |                      |                      |                      |                      |          r89         |          r89         |          r89         |                      |                      |          r89         |          r89         |                      |          r89         |                      |                      |                      |                      |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |                      |                      |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |                      |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |                      |                      |          r89         |          r89         |          r89         |                      |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |                      |                      |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |                      |                      |                      |                      |                      |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |                      |          r89         |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |                      |                      |                      |                      |          r89         |          r89         |          r89        ...
# +----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-------------------- ...

# %% [markdown]
# ## Text Pre-processing

# %%
# READING INPUT FROM FILE

inputFile = open('input.txt', 'r')
inputText = inputFile.read()
text = inputText.replace('\n', ' ')
inputFile.close()
text
# Out:
# 'She were writing a letter to Ishwarya. My teacher teaches well. She went to school. Raj is climbs a mountian. Raj plays fotball well. Mom cook delisious food. Navvya is a topper. Ishwarya is a kabbadi player. Ishwarya will sings a song in the show. These people is from Canada.'

# %%
# OUTPUT REPORT

outputLines = []
outputLines.append("ANALYSIS REPORT : \n\n")
outputLines.append("---------------------------------------------\n\n")

# %%
# SENTENCE TOKENIZATION

stop_Char=["!",".","?",";"]

sentences=[]

sentence=""
for ch in text :
  if ch not in stop_Char:
    sentence += ch
  else :
    sentence = sentence.strip()
    sentences.append(sentence)
    sentence=""  

sentenceCount = len(sentences) 
print("Sentence count : " + str(sentenceCount))

for sentence in sentences :
  print(sentence)
# Out:
# Sentence count : 10
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# REMOVAL OF STOP CHARACTERS

reqSplChars = ["@", "&", "(", ")", "-"]
splChars = ["#", "%", "&", "^", "$", "*", "`", "+"]
punctuation = [",", ".", "!"]

exclude = splChars + punctuation
cleanSentences=[]
for sentence in sentences :
  cleantext=""
  for ch in sentence :
    if ch not in exclude:
      cleantext += ch
  cleanSentences.append(cleantext)

for cleanSentence in cleanSentences :
  print(cleanSentence)
# Out:
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# WORD TOKENIZATION

wordsArray = []
wordsCount = []
for cleanText in cleanSentences :
  words = []
  word = ""
  i = 0
  while(i < len(cleanText)):
    if(cleanText[i] == " "):
      i += 1
    else:
      word = ""
      while(i < len(cleanText) and cleanText[i] != " "):
        word += cleanText[i]
        i += 1
      if(len(word) > 0):
        words.append(word)
  wordsArray.append(words)
  wordsCount.append(len(words))

totalWordCount = sum(wordsCount)

for i in range(sentenceCount) :
  print(wordsArray[i])
  print("Word count : " + str(wordsCount[i]))
  print()

print("Total word count : " + str(totalWordCount))
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Word count : 7
#
# ['My', 'teacher', 'teaches', 'well']
# Word count : 4
#
# ['She', 'went', 'to', 'school']
# Word count : 4
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word count : 5
#
# ['Raj', 'plays', 'fotball', 'well']
# Word count : 4
#
# ['Mom', 'cook', 'delisious', 'food']
# Word count : 4
#
# ['Navvya', 'is', 'a', 'topper']
# Word count : 4
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word count : 5
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Word count : 8
#
# ['These', 'people', 'is', 'from', 'Canada']
# Word count : 5
#
# Total word count : 50

# %%
# Spell Check

spell = SpellChecker()

correctedWordsArray = []
misspelledCount = []
misspelledResult = []
for words in wordsArray : 
  count = 0
  misspelled = spell.unknown(words)
  
  if(len(misspelled) > 0):
    print(words)
    for word in misspelled:
        if(word not in properNouns) :
          count += 1
          print("Word : " + word)
          print("Best match : " + str(spell.correction(word)))
          print("Possible matches : " + str(spell.candidates(word)))
          misspelledResult.append("Misspelled word : {}\nBest match : {}\nPossible matches : {}\n\n".format(word, str(spell.correction(word)), str(spell.candidates(word))))
    print("Misspelled word count : " + str(count))
    misspelledCount.append(count)
    print()
    
    # Correcting the misspelled words
    correctedWords = []
    for word in words :
      if word in misspelled :
        correctedWords.append((spell.correction(word)).lower())
      else :
        correctedWords.append(word.lower())
    correctedWordsArray.append(correctedWords)
  else :
    correctedWords = [word.lower() for word in words]
    correctedWordsArray.append(correctedWords)
    print(words)
    print("Misspelled word count : " + str(len(misspelled)))
    print()
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Misspelled word count : 0
#
# ['My', 'teacher', 'teaches', 'well']
# Misspelled word count : 0
#
# ['She', 'went', 'to', 'school']
# Misspelled word count : 0
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word : mountian
# Best match : mountain
# Possible matches : {'mountain'}
# Misspelled word count : 1
#
# ['Raj', 'plays', 'fotball', 'well']
# Word : fotball
# Best match : football
# Possible matches : {'fooball', 'football', 'ootball'}
# Misspelled word count : 1
#
# ['Mom', 'cook', 'delisious', 'food']
# Word : delisious
# Best match : delicious
# Possible matches : {'delicious', 'delirious'}
# Misspelled word count : 1
#
# ['Navvya', 'is', 'a', 'topper']
# Misspelled word count : 0
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word : kabbadi
# Best match : kabaddi
# Possible matches : {'kabaddi'}
# Misspelled word count : 1
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Misspelled word count : 0
#
# ['These', 'people', 'is', 'from', 'Canada']
# Misspelled word count : 0

# %%
totalMispelledCount = sum(misspelledCount)
print("Total misspelled words : " + str(totalMispelledCount))

print("Array of words with correct spelling : ")
for words in correctedWordsArray :
  print(words)
# Out:
# Total misspelled words : 4
# Array of words with correct spelling :
# ['she', 'were', 'writing', 'a', 'letter', 'to', 'ishwarya']
# ['my', 'teacher', 'teaches', 'well']
# ['she', 'went', 'to', 'school']
# ['raj', 'is', 'climbs', 'a', 'mountain']
# ['raj', 'plays', 'football', 'well']
# ['mom', 'cook', 'delicious', 'food']
# ['navvya', 'is', 'a', 'topper']
# ['ishwarya', 'is', 'a', 'kabaddi', 'player']
# ['ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# ['these', 'people', 'is', 'from', 'canada']

# %%
outputLines.append("Sentence Count : {}\n".format(sentenceCount))
outputLines.append("Word Count : {}\n".format(totalWordCount))
outputLines.append("Misspelled Count : {}\n\n".format(totalMispelledCount))
outputLines.append("---------------------------------------------\n\n")
for result in misspelledResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %% [markdown]
# ## Evaluation of Grammar Correctness
#
# Input : SLR(1) Parsing table, input sentences
#
# Output : Analysis report of the input
#
#
# -> Stack immplementation of input sentence
#
# -> Semantic analysis using NLP
#
# -> Genration of report

# %%
# Stack implementaion of input strings

def LR_parser(slr, w):
  isAccepted = False
  buffer = [x for x in w]
  buffer.append('$')
  pointer = 0
  a = buffer[pointer]
  stack = ['0']
  symbols = ['']
  results = {'step': [''], 'stack': ['STACK'] + stack, 'symbols': ['SYMBOLS'] + symbols, 'input': ['INPUT'], 'action': ['ACTION']}

  step = 0
  while True:
    s = int(stack[-1])
    step += 1
    results['step'].append(f'({step})')
    results['input'].append(' '.join(buffer[pointer:]))

    if a not in slr.parse_table[s]:
      results['action'].append(f'ERROR: unrecognized symbol {a}')
      isAccepted = False
      break

    elif not slr.parse_table[s][a]:
      results['action'].append('ERROR: input cannot be parsed by given grammar')
      isAccepted = False
      break

    elif '/' in slr.parse_table[s][a]:
      action = 'reduce' if slr.parse_table[s][a].count('r') > 1 else 'shift'
      results['action'].append(f'ERROR: {action}-reduce conflict at state {s}, symbol {a}')
      isAccepted = False
      break

    elif slr.parse_table[s][a].startswith('s'):
      results['action'].append('shift')
      stack.append(slr.parse_table[s][a][1:])
      symbols.append(a)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))
      pointer += 1
      a = buffer[pointer]

    elif slr.parse_table[s][a].startswith('r'):
      head, body = slr.G_indexed[int(slr.parse_table[s][a][1:])]
      results['action'].append(f'reduce by {head} -> {" ".join(body)}')

      if body != ('^',):
        stack = stack[:-len(body)]
        symbols = symbols[:-len(body)]

      stack.append(str(slr.parse_table[int(stack[-1])][head]))
      symbols.append(head)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))

    elif slr.parse_table[s][a] == 'acc':
      results['action'].append('accept')
      isAccepted = True
      break

  # Printing results
  def print_line():
    print(f'{"".join(["+" + ("-" * (max_len + 2)) for max_len in max_lens.values()])}+')

  max_lens = {key: max(len(value) for value in results[key]) for key in results}
  justs = {'step': '>', 'stack': '', 'symbols': '', 'input': '>', 'action': ''}

  print_line()
  print(''.join([f'| {history[0]:^{max_len}} ' for history, max_len in zip(results.values(), max_lens.values())]) + '|')
  print_line()
  for i, step in enumerate(results['step'][:-1], 1):
    print(''.join([f'| {history[i]:{just}{max_len}} ' for history, just, max_len in zip(results.values(), justs.values(), max_lens.values())]) + '|')

  print_line()

  return isAccepted

# %%
incorrectSentenceCount = 0
incorrectSentenceResult = []
for input_text in correctedWordsArray :
  isAccepted = LR_parser(slr, input_text)
  # Performing semantic analysis  using nlp for grammar corrections
  if(not isAccepted) :
    print("Correction : ")
    correction = GingerIt().parse(" ".join(input_text))['result']
    print(correction)
    incorrectSentenceCount += 1
    incorrectSentenceResult.append("Incorrect sentence : {}\nCorrection : {}\n\n".format(" ".join(input_text), correction))
# Out:
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                  |                     ACTION                     |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# | (1) | 0         |             | she were writing a letter to ishwarya $ | shift                                          |
# | (2) | 0 100     |  she        |     were writing a letter to ishwarya $ | reduce by PRONOUN_SG -> she                    |
# | (3) | 0 183     |  PRONOUN_SG |     were writing a letter to ishwarya $ | reduce by NP_SG -> PRONOUN_SG                  |
# | (4) | 0 177     |  NP_SG      |     were writing a letter to ishwarya $ | shift                                          |
# | (5) | 0 177 280 |  NP_SG were |          writing a letter to ishwarya $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# Correction :
# she was writing a letter to ishwarya
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |      |     STACK     |       SYMBOLS       |           INPUT           |                ACTION                |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |  (1) | 0             |                     | my teacher teaches well $ | shift                                |
# |  (2) | 0 178         |  my                 |    teacher teaches well $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 183         |  PRONOUN_SG         |    teacher teaches well $ | shift                                |
# |  (4) | 0 183 76      |  PRONOUN_SG teacher |            teaches well $ | reduce by NOUN_SG -> teacher         |
# |  (5) | 0 183 159     |  PRONOUN_SG NOUN_SG |            teaches well $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 183 294     |  PRONOUN_SG NOM_SG  |            teaches well $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 177         |  NP_SG              |            teaches well $ | shift                                |
# |  (8) | 0 177 274     |  NP_SG teaches      |                    well $ | reduce by V1_SG -> teaches           |
# |  (9) | 0 177 272     |  NP_SG V1_SG        |                    well $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 177 285     |  NP_SG PRES_SG      |                    well $ | shift                                |
# | (11) | 0 177 285 34  |  NP_SG PRES_SG well |                         $ | reduce by ADV -> well                |
# | (12) | 0 177 285 302 |  NP_SG PRES_SG ADV  |                         $ | reduce by S1 -> ADV                  |
# | (13) | 0 177 285 403 |  NP_SG PRES_SG S1   |                         $ | reduce by S -> NP_SG PRES_SG S1      |
# | (14) | 0 129         |  S                  |                         $ | accept                               |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |      |       STACK       |          SYMBOLS           |        INPUT         |            ACTION             |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |  (1) | 0                 |                            | she went to school $ | shift                         |
# |  (2) | 0 100             |  she                       |     went to school $ | reduce by PRONOUN_SG -> she   |
# |  (3) | 0 183             |  PRONOUN_SG                |     went to school $ | reduce by NP_SG -> PRONOUN_SG |
# |  (4) | 0 177             |  NP_SG                     |     went to school $ | shift                         |
# |  (5) | 0 177 226         |  NP_SG went                |          to school $ | reduce by V2 -> went          |
# |  (6) | 0 177 238         |  NP_SG V2                  |          to school $ | reduce by PAST -> V2          |
# |  (7) | 0 177 275         |  NP_SG PAST                |          to school $ | shift                         |
# |  (8) | 0 177 275 300     |  NP_SG PAST to             |             school $ | reduce by PREPOS -> to        |
# |  (9) | 0 177 275 308     |  NP_SG PAST PREPOS         |             school $ | shift                         |
# | (10) | 0 177 275 308 186 |  NP_SG PAST PREPOS school  |                    $ | reduce by NOUN_SG -> school   |
# | (11) | 0 177 275 308 159 |  NP_SG PAST PREPOS NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG   |
# | (12) | 0 177 275 308 74  |  NP_SG PAST PREPOS NOM_SG  |                    $ | reduce by NP_SG -> NOM_SG     |
# | (13) | 0 177 275 308 411 |  NP_SG PAST PREPOS NP_SG   |                    $ | reduce by PP -> PREPOS NP_SG  |
# | (14) | 0 177 275 298     |  NP_SG PAST PP             |                    $ | reduce by NP -> PP            |
# | (15) | 0 177 275 306     |  NP_SG PAST NP             |                    $ | reduce by S1 -> NP            |
# | (16) | 0 177 275 399     |  NP_SG PAST S1             |                    $ | reduce by S -> NP_SG PAST S1  |
# | (17) | 0 129             |  S                         |                    $ | accept                        |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |           INPUT            |                     ACTION                     |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# | (1) | 0         |             | raj is climbs a mountain $ | shift                                          |
# | (2) | 0 88      |  raj        |     is climbs a mountain $ | reduce by PROPERNOUN -> raj                    |
# | (3) | 0 20      |  PROPERNOUN |     is climbs a mountain $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 177     |  NP_SG      |     is climbs a mountain $ | shift                                          |
# | (5) | 0 177 271 |  NP_SG is   |        climbs a mountain $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# Correction :
# raj climbs a mountain
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |      |     STACK     |         SYMBOLS         |           INPUT           |             ACTION              |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |  (1) | 0             |                         | raj plays football well $ | shift                           |
# |  (2) | 0 88          |  raj                    |     plays football well $ | reduce by PROPERNOUN -> raj     |
# |  (3) | 0 20          |  PROPERNOUN             |     plays football well $ | reduce by NP_SG -> PROPERNOUN   |
# |  (4) | 0 177         |  NP_SG                  |     plays football well $ | shift                           |
# |  (5) | 0 177 270     |  NP_SG plays            |           football well $ | reduce by V1_SG -> plays        |
# |  (6) | 0 177 272     |  NP_SG V1_SG            |           football well $ | reduce by PRES_SG -> V1_SG      |
# |  (7) | 0 177 285     |  NP_SG PRES_SG          |           football well $ | shift                           |
# |  (8) | 0 177 285 142 |  NP_SG PRES_SG football |                    well $ | reduce by NOUN_SG -> football   |
# |  (9) | 0 177 285 159 |  NP_SG PRES_SG NOUN_SG  |                    well $ | reduce by NOM_SG -> NOUN_SG     |
# | (10) | 0 177 285 74  |  NP_SG PRES_SG NOM_SG   |                    well $ | reduce by NP_SG -> NOM_SG       |
# | (11) | 0 177 285 313 |  NP_SG PRES_SG NP_SG    |                    well $ | reduce by NP -> NP_SG           |
# | (12) | 0 177 285 306 |  NP_SG PRES_SG NP       |                    well $ | reduce by S1 -> NP              |
# | (13) | 0 177 285 403 |  NP_SG PRES_SG S1       |                    well $ | reduce by S -> NP_SG PRES_SG S1 |
# | (14) | 0 129         |  S                      |                    well $ | shift                           |
# | (15) | 0 129 34      |  S well                 |                         $ | reduce by ADV -> well           |
# | (16) | 0 129 260     |  S ADV                  |                         $ | reduce by S -> S ADV            |
# | (17) | 0 129         |  S                      |                         $ | accept                          |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# +-----+-------+----------+---------------------------+------------------------------------------------+
# |     | STACK | SYMBOLS  |           INPUT           |                     ACTION                     |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# | (1) | 0     |          | mom cook delicious food $ | shift                                          |
# | (2) | 0 102 |  mom     |     cook delicious food $ | reduce by NOUN_SG -> mom                       |
# | (3) | 0 159 |  NOUN_SG |     cook delicious food $ | reduce by NOM_SG -> NOUN_SG                    |
# | (4) | 0 74  |  NOM_SG  |     cook delicious food $ | reduce by NP_SG -> NOM_SG                      |
# | (5) | 0 177 |  NP_SG   |     cook delicious food $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# Correction :
# mom cooks delicious food
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |      |      STACK       |            SYMBOLS            |        INPUT         |              ACTION              |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |  (1) | 0                |                               | navvya is a topper $ | shift                            |
# |  (2) | 0 165            |  navvya                       |        is a topper $ | reduce by PROPERNOUN -> navvya   |
# |  (3) | 0 20             |  PROPERNOUN                   |        is a topper $ | reduce by NP_SG -> PROPERNOUN    |
# |  (4) | 0 177            |  NP_SG                        |        is a topper $ | shift                            |
# |  (5) | 0 177 271        |  NP_SG is                     |           a topper $ | reduce by V1_SG -> is            |
# |  (6) | 0 177 272        |  NP_SG V1_SG                  |           a topper $ | reduce by PRES_SG -> V1_SG       |
# |  (7) | 0 177 285        |  NP_SG PRES_SG                |           a topper $ | shift                            |
# |  (8) | 0 177 285 120    |  NP_SG PRES_SG a              |             topper $ | reduce by DET_SG -> a            |
# |  (9) | 0 177 285 97     |  NP_SG PRES_SG DET_SG         |             topper $ | shift                            |
# | (10) | 0 177 285 97 10  |  NP_SG PRES_SG DET_SG topper  |                    $ | reduce by NOUN_SG -> topper      |
# | (11) | 0 177 285 97 159 |  NP_SG PRES_SG DET_SG NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG      |
# | (12) | 0 177 285 97 253 |  NP_SG PRES_SG DET_SG NOM_SG  |                    $ | reduce by NP_SG -> DET_SG NOM_SG |
# | (13) | 0 177 285 313    |  NP_SG PRES_SG NP_SG          |                    $ | reduce by NP -> NP_SG            |
# | (14) | 0 177 285 306    |  NP_SG PRES_SG NP             |                    $ | reduce by S1 -> NP               |
# | (15) | 0 177 285 403    |  NP_SG PRES_SG S1             |                    $ | reduce by S -> NP_SG PRES_SG S1  |
# | (16) | 0 129            |  S                            |                    $ | accept                           |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# |      |        STACK         |               SYMBOLS                |             INPUT              |               ACTION               |
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# |  (1) | 0                    |                                      | ishwarya is a kabaddi player $ | shift                              |
# |  (2) | 0 149                |  ishwarya                            |          is a kabaddi player $ | reduce by PROPERNOUN -> ishwarya   |
# |  (3) | 0 20                 |  PROPERNOUN                          |          is a kabaddi player $ | reduce by NP_SG -> PROPERNOUN      |
# |  (4) | 0 177                |  NP_SG                               |          is a kabaddi player $ | shift                              |
# |  (5) | 0 177 271            |  NP_SG is                            |             a kabaddi player $ | reduce by V1_SG -> is              |
# |  (6) | 0 177 272            |  NP_SG V1_SG                         |             a kabaddi player $ | reduce by PRES_SG -> V1_SG         |
# |  (7) | 0 177 285            |  NP_SG PRES_SG                       |             a kabaddi player $ | shift                              |
# |  (8) | 0 177 285 120        |  NP_SG PRES_SG a                     |               kabaddi player $ | reduce by DET_SG -> a              |
# |  (9) | 0 177 285 97         |  NP_SG PRES_SG DET_SG                |               kabaddi player $ | shift                              |
# | (10) | 0 177 285 97 24      |  NP_SG PRES_SG DET_SG kabaddi        |                       player $ | reduce by NOUN_SG -> kabaddi       |
# | (11) | 0 177 285 97 159     |  NP_SG PRES_SG DET_SG NOUN_SG        |                       player $ | reduce by NOM_SG -> NOUN_SG        |
# | (12) | 0 177 285 97 253     |  NP_SG PRES_SG DET_SG NOM_SG         |                       player $ | shift                              |
# | (13) | 0 177 285 97 253 121 |  NP_SG PRES_SG DET_SG NOM_SG player  |                              $ | reduce by NOUN_SG -> player        |
# | (14) | 0 177 285 97 253 250 |  NP_SG PRES_SG DET_SG NOM_SG NOUN_SG |                              $ | reduce by NOM_SG -> NOM_SG NOUN_SG |
# | (15) | 0 177 285 97 253     |  NP_SG PRES_SG DET_SG NOM_SG         |                              $ | reduce by NP_SG -> DET_SG NOM_SG   |
# | (16) | 0 177 285 313        |  NP_SG PRES_SG NP_SG                 |                              $ | reduce by NP -> NP_SG              |
# | (17) | 0 177 285 306        |  NP_SG PRES_SG NP                    |                              $ | reduce by S1 -> NP                 |
# | (18) | 0 177 285 403        |  NP_SG PRES_SG S1                    |                              $ | reduce by S -> NP_SG PRES_SG S1    |
# | (19) | 0 129                |  S                                   |                              $ | accept                             |
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                   |                     ACTION                     |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# | (1) | 0         |             | ishwarya will sings a song in the show $ | shift                                          |
# | (2) | 0 149     |  ishwarya   |          will sings a song in the show $ | reduce by PROPERNOUN -> ishwarya               |
# | (3) | 0 20      |  PROPERNOUN |          will sings a song in the show $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 177     |  NP_SG      |          will sings a song in the show $ | shift                                          |
# | (5) | 0 177 216 |  NP_SG will |               sings a song in the show $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# Correction :
# Ishwarya will sing a song in the show
# +-----+---------+-----------------+-------------------------------+------------------------------------------------+
# |     |  STACK  |     SYMBOLS     |             INPUT             |                     ACTION                     |
# +-----+---------+-----------------+-------------------------------+------------------------------------------------+
# | (1) | 0       |                 | these people is from canada $ | shift                                          |
# | (2) | 0 11    |  these          |       people is from canada $ | reduce by DET_PL -> these                      |
# | (3) | 0 7     |  DET_PL         |       people is from canada $ | shift                                          |
# | (4) | 0 7 179 |  DET_PL people  |              is from canada $ | reduce by NOUN_PL -> people                    |
# | (5) | 0 7 73  |  DET_PL NOUN_PL |              is from canada $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 7 246 |  DET_PL NOM_PL  |              is from canada $ | reduce by NP_PL -> DET_PL NOM_PL               |
# | (7) | 0 6     |  NP_PL          |              is from canada $ | ERROR: input cannot be parsed by given grammar |
# +-----+---------+-----------------+-------------------------------+------------------------------------------------+
# Correction :
# these people are from Canada

# %%
outputLines.append("Incorrect sentences count : {}\n\n".format(incorrectSentenceCount))
outputLines.append("---------------------------------------------\n\n")
for result in incorrectSentenceResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# WRITING RESULT TO THE OUTPUT FILE

outputFile = open("output.txt", "w")
for line in outputLines:
  outputFile.write(line)
outputFile.close()
