# %% [markdown]
# <a href="https://colab.research.google.com/github/AjiteshMahalingam/GoGrammar_Writing_Aid/blob/main/GoGrammar_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.6.2)

# %%
pip install gingerit
# Out:
# Requirement already satisfied: gingerit in /usr/local/lib/python3.7/dist-packages (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.7/dist-packages (from gingerit) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2021.10.8)

# %%
from gingerit.gingerit import GingerIt
from spellchecker import SpellChecker

# %% [markdown]
# ## Module 1 - Text Pre-processing

# %%
# READING INPUT FROM FILE

inputFile = open('input.txt', 'r')
inputText = inputFile.read()
text = inputText.replace('\n', ' ')
inputFile.close()
text
# Out:
# 'She were writing a letter to Ishwarya. My teacher teaches well. She went to school. Raj is climbs a mountian. Raj plays fotball well. Mom cook delisious food. Navvya is a topper. Ishwarya is a kabbadi player. Ishwarya will sings a song in the show. These people is from Canada.'

# %%
# OUTPUT REPORT

outputLines = []
outputLines.append("ANALYSIS REPORT : \n\n")
outputLines.append("---------------------------------------------\n\n")

# %%
# SENTENCE TOKENIZATION

stop_Char=["!",".","?",";"]

sentences=[]

sentence=""
for ch in text :
  if ch not in stop_Char:
    sentence += ch
  else :
    sentence = sentence.strip()
    sentences.append(sentence)
    sentence=""  

sentenceCount = len(sentences) 
print("Sentence count : " + str(sentenceCount))

for sentence in sentences :
  print(sentence)
# Out:
# Sentence count : 10
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# REMOVAL OF STOP CHARACTERS

reqSplChars = ["@", "&", "(", ")", "-"]
splChars = ["#", "%", "&", "^", "$", "*", "`", "+"]
punctuation = [",", ".", "!"]

exclude = splChars + punctuation
cleanSentences=[]
for sentence in sentences :
  cleantext=""
  for ch in sentence :
    if ch not in exclude:
      cleantext += ch
  cleanSentences.append(cleantext)

for cleanSentence in cleanSentences :
  print(cleanSentence)
# Out:
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# WORD TOKENIZATION

wordsArray = []
wordsCount = []
for cleanText in cleanSentences :
  words = []
  word = ""
  i = 0
  while(i < len(cleanText)):
    if(cleanText[i] == " "):
      i += 1
    else:
      word = ""
      while(i < len(cleanText) and cleanText[i] != " "):
        word += cleanText[i]
        i += 1
      if(len(word) > 0):
        words.append(word)
  wordsArray.append(words)
  wordsCount.append(len(words))

totalWordCount = sum(wordsCount)

for i in range(sentenceCount) :
  print(wordsArray[i])
  print("Word count : " + str(wordsCount[i]))
  print()

print("Total word count : " + str(totalWordCount))
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Word count : 7
#
# ['My', 'teacher', 'teaches', 'well']
# Word count : 4
#
# ['She', 'went', 'to', 'school']
# Word count : 4
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word count : 5
#
# ['Raj', 'plays', 'fotball', 'well']
# Word count : 4
#
# ['Mom', 'cook', 'delisious', 'food']
# Word count : 4
#
# ['Navvya', 'is', 'a', 'topper']
# Word count : 4
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word count : 5
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Word count : 8
#
# ['These', 'people', 'is', 'from', 'Canada']
# Word count : 5
#
# Total word count : 50

# %%
# Spell Check

spell = SpellChecker()

correctedWordsArray = []
misspelledCount = []
misspelledResult = []
for words in wordsArray : 
  misspelled = spell.unknown(words)
  misspelledCount.append(len(misspelled))
  if(len(misspelled) > 0):
    print(words)
    print("Misspelled words : " + str(misspelled))
    print("Misspelled word count : " + str(len(misspelled)))
    for word in misspelled:
        print("Best match : " + str(spell.correction(word)))
        print("Possible matches : " + str(spell.candidates(word)))
        misspelledResult.append("Misspelled word : {}\nBest match : {}\nPossible matches : {}\n\n".format(word, str(spell.correction(word)), str(spell.candidates(word))))
    print()
    
    # Correcting the misspelled words
    correctedWords = []
    for word in words :
      if word in misspelled :
        correctedWords.append((spell.correction(word)).lower())
      else :
        correctedWords.append(word.lower())
    correctedWordsArray.append(correctedWords)
  else :
    correctedWords = [word.lower() for word in words]
    correctedWordsArray.append(correctedWords)
    print(words)
    print("Misspelled word count : " + str(len(misspelled)))
    print()
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Misspelled words : {'ishwarya'}
# Misspelled word count : 1
# Best match : ishwarya
# Possible matches : {'ishwarya'}
#
# ['My', 'teacher', 'teaches', 'well']
# Misspelled word count : 0
#
# ['She', 'went', 'to', 'school']
# Misspelled word count : 0
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Misspelled words : {'mountian'}
# Misspelled word count : 1
# Best match : mountain
# Possible matches : {'mountain'}
#
# ['Raj', 'plays', 'fotball', 'well']
# Misspelled words : {'fotball'}
# Misspelled word count : 1
# Best match : football
# Possible matches : {'ootball', 'football', 'fooball'}
#
# ['Mom', 'cook', 'delisious', 'food']
# Misspelled words : {'delisious'}
# Misspelled word count : 1
# Best match : delicious
# Possible matches : {'delirious', 'delicious'}
#
# ['Navvya', 'is', 'a', 'topper']
# Misspelled words : {'navvya'}
# Misspelled word count : 1
# Best match : navvy
# Possible matches : {'navvy'}
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Misspelled words : {'ishwarya', 'kabbadi'}
# Misspelled word count : 2
# Best match : ishwarya
# Possible matches : {'ishwarya'}
# Best match : kabaddi
# Possible matches : {'kabaddi'}
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Misspelled words : {'ishwarya'}
# Misspelled word count : 1
# Best match : ishwarya
# Possible matches : {'ishwarya'}
#
# ['These', 'people', 'is', 'from', 'Canada']
# Misspelled word count : 0

# %%
totalMispelledCount = sum(misspelledCount)
print("Total misspelled words : " + str(totalMispelledCount))

print("Array of words with correct spelling : ")
for words in correctedWordsArray :
  print(words)
# Out:
# Total misspelled words : 8
# Array of words with correct spelling :
# ['she', 'were', 'writing', 'a', 'letter', 'to', 'ishwarya']
# ['my', 'teacher', 'teaches', 'well']
# ['she', 'went', 'to', 'school']
# ['raj', 'is', 'climbs', 'a', 'mountain']
# ['raj', 'plays', 'football', 'well']
# ['mom', 'cook', 'delicious', 'food']
# ['navvya', 'is', 'a', 'topper']
# ['ishwarya', 'is', 'a', 'kabaddi', 'player']
# ['ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# ['these', 'people', 'is', 'from', 'canada']

# %%
outputLines.append("Sentence Count : {}\n".format(sentenceCount))
outputLines.append("Word Count : {}\n".format(totalWordCount))
outputLines.append("Misspelled Count : {}\n\n".format(totalMispelledCount))
outputLines.append("---------------------------------------------\n\n")
for result in misspelledResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %% [markdown]
# ## Module 2 - Construction of English Grammar
#
# Input : English Grammar specifications file
#
# Output : Grammar object
#
# -> English Grammar string processing
#
# -> Construction of Grammar class

# %%
# READING GRAMMAR SPECIFICATIONS

inputFile = open('grammar.txt', 'r')
inputText = inputFile.read()
grammarRules = [ rule.strip() for rule in inputText.split("\n")]
grammarRules
# Out:
# ['S -> NP_SG PAST S1 | NP_SG PAST_PERFECT S1 | NP_SG PAST_CONT_SG S1 | NP_SG PAST_PERFECT_CONT S1 | NP_SG PRES_SG S1 | NP_SG PRES_PERFECT_SG S1 | NP_SG PRES_CONT_SG S1 | NP_SG PRES_PERFECT_CONT_SG S1 | NP_SG FUTURE S1 | NP_SG FUTURE_PERFECT S1 | NP_SG FUTURE_CONT S1 | NP_SG FUTURE_PERFECT_CONT S1 | NP_PL PAST S1 | NP_PL PAST_PERFECT S1 | NP_PL PAST_CONT_PL S1 | NP_PL PAST_PERFECT_CONT S1 | NP_PL PRES_PL S1  | NP_PL PRES_PERFECT_PL S1 | NP_PL PRES_CONT_PL S1 | NP_PL PRES_PERFECT_CONT_PL S1 | NP_PL FUTURE S1 | NP_PL FUTURE_PERFECT S1 | NP_PL FUTURE_CONT S1 | NP_PL FUTURE_PERFECT_CONT S1 | S ADV',
#  'S1 -> NP | ADV',
#  'NP -> NP_SG | NP_PL | PP | NP PP',
#  'NP_SG ->  PRONOUN_SG | PRONOUN_SG NOM_SG| PROPERNOUN | NOM_SG | DET_SG NOM_SG | DET_BOTH NOM_SG | ADV NP_SG | NP_SG CONJ NP',
#  'NOM_SG -> NOUN_SG | ADJ NOUN_SG | NOM_SG NOUN_SG',
#  'NP_PL -> PRONOUN_PL | PRONOUN_PL NOM_PL| NOM_PL | DET_PL NOM_PL | DET_BOTH NOM_PL | ADV NP_PL | NP_PL CONJ NP',
#  'NOM_PL -> NOUN_PL | ADJ NOUN_PL | NOM_PL NOUN_PL',
#  'PP -> PREPOS NP_SG | PREPOS NP_PL',
#  'PAST -> V2 | ADV V2',
#  'PAST_PERFECT -> had V3 | had ADV V3',
#  'PAST_CONT_SG -> was GERUNDV | was ADV GERUNDV',
#  'PAST_CONT_PL -> were GERUNDV | were ADV GERUNDV',
#  'PAST_PERFECT_CONT -> had been GERUNDV | had ADV been GERUNDV',
#  'PRES_SG -> V1_SG | ADV V1_SG',
#  'PRES_PL -> V1_PL | ADV V1_PL',
#  'PRES_PERFECT_SG -> has V3 | has ADV V3',
#  'PRES_PERFECT_PL -> have V3 | have ADV V3',
#  'PRES_CONT_SG -> is GERUNDV | is ADV GERUNDV',
#  'PRES_CONT_PL -> are GERUNDV | are ADV GERUNDV',
#  'PRES_PERFECT_CONT_SG -> has been GERUNDV | has ADV been GERUNDV | has been | has ADV been',
#  'PRES_PERFECT_CONT_PL -> have been GERUNDV | have ADV been GERUNDV',
#  'FUTURE -> will V1_PL | will ADV V1_PL',
#  'FUTURE_PERFECT -> will have V3 | will have ADV V3',
#  'FUTURE_CONT -> will be GERUNDV | will ADV be GERUNDV',
#  'FUTURE_PERFECT_CONT -> will have been GERUNDV | will have ADV been GERUNDV',
#  'PRONOUN_SG -> my | she | he | it | him | i | her | his',
#  'PRONOUN_PL -> they | us | you | we | their',
#  'RELPR_SG -> which',
#  'RELPR_PL -> whom',
#  'PROPERNOUN -> ishwarya | joseph | india | germany | ajitesh | navvya | ritheesh | switzerland | paris | wednesday | january | may | turkey | easter | november | raj | canada | america | john',
#  'NOUN_SG -> sentence | me | kabaddi | friend | patient | parcel | player | moment | morning | grandfather | outlet | evening | programming | building | thinking | mom | weekend | brother | basketball | afternoon | book | accountant | milk | accident | neighbourhood | car | phone | night | airplane | fog | street | dad | bed | fire | house | zoo | cold | pope | cup | sister | party | tea | weather | call | baby | movie | picture | pilot | airport | assignment | week | month | room | homework | husband | year | school | teacher | letter | football | food | mountain | wife | topper | song | show | garden | album',
#  'NOUN_PL -> roses | mountains | goats | films | times | emails | people | children |  specialists | girls | parents | jacksons | cows | boys | books | years | portraits | friends | ages | weeks | letters | peacocks | books',
#  'DET_SG -> a | an | this | that',
#  'DET_PL -> these | all | many | no',
#  'DET_BOTH -> the',
#  'CONJ -> and | but | because | while',
#  'ADJ -> red | delicious | first | few | two | four | three | fun | since | sweet | nice | severe | terrible | hungry | new | whole | last | every | critical',
#  'ADV -> well | gracefully | before | next | very | when | not | whereabouts | constantly | lately | yesterday | ago | tomorrow | early | still | twice | always | already | past | never | today | never | recently | heavily',
#  'PREPOS -> at | in | of | for | by | from | far | on | around | as | to | down',
#  'V1_SG -> climbs | teaches | plays | cooks | is | likes | be | know | am | draws | works | understands | invloves | sings',
#  'V1_PL -> teach | are | sing | give | think | rain | turn | go | see | do | take | study | speak | drink | cook',
#  'GERUNDV -> teaching | running | writing | opening | burning | feeling | enjoying | living | spending | ringing | repairing | visiting | having | climbing | getting | meeting | playing | cleaning | going | looking | suffering | raining | waiting | studying | snowing | seeing | dating | taking | listening | dancing',
#  'V2 -> taught | were | was | went | knew | would | started | received | gave | caught | married | understood | flew | drink | read | made | tired | saw | did',
#  'V3 -> seen | written | given | done | gone | made | flown | painted | fed | met | finished | acted | watched']

# %%
class Grammar :
  def __init__(self, grammarStr) :
    self.input = grammarStr
    self.symbols = set()
    self.terminals = set()
    self.nonterminals = set()
    self.startSymbol = None
    self.grammar = {}

    for production in grammarStr :
      # The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
      head, _, bodies = production.partition(' -> ')
      
      # The nonterminal of the first production is considered to be the start symbol
      if self.startSymbol is None :
        self.startSymbol = head

      self.grammar.setdefault(head, set())
      self.nonterminals.add(head)

      bodies = {tuple(body.strip().split(" ")) for body in ' '.join(bodies.split(" ")).split('|') }

      for body in bodies :
        self.grammar[head].add(body)
        for symbol in body :
          if symbol.isupper() :
            self.nonterminals.add(symbol)
          else :
            self.terminals.add(symbol)  
    
    self.symbols = self.nonterminals | self.terminals

  def __str__ (self) :
    print("Start Symbol : " , self.startSymbol)
    print("Non-terminals : " , self.nonterminals)
    print("Terminals : " , self.terminals)
    print("Productions : ")
    for head in self.grammar :
      for body in self.grammar[head] :
        print(head, "->", body)
    return ""

# %%
G = Grammar(grammarRules)
print(G)
# Out:
# Start Symbol :  S
# Non-terminals :  {'FUTURE_PERFECT', 'NOUN_PL', 'PROPERNOUN', 'V2', 'V1_SG', 'PRONOUN_SG', 'FUTURE_PERFECT_CONT', 'DET_SG', 'RELPR_SG', 'CONJ', 'RELPR_PL', 'S', 'PAST_PERFECT_CONT', 'PP', 'NOUN_SG', 'V1_PL', 'PAST_CONT_PL', 'DET_PL', 'FUTURE_CONT', 'PRES_PERFECT_SG', 'ADV', 'PRES_CONT_SG', 'PRES_PERFECT_CONT_PL', 'PRES_PERFECT_CONT_SG', 'DET_BOTH', 'PRES_SG', 'PAST_PERFECT', 'NP_SG', 'NP_PL', 'PRES_CONT_PL', 'NP', 'ADJ', 'PAST', 'FUTURE', 'PAST_CONT_SG', 'PREPOS', 'S1', 'V3', 'NOM_PL', 'NOM_SG', 'PRONOUN_PL', 'PRES_PL', 'PRES_PERFECT_PL', 'GERUNDV'}
# Terminals :  {'would', 'and', 'she', 'show', 'weekend', 'did', 'an', 'airport', 'dating', 'to', 'wife', 'specialists', 'am', 'met', 'done', 'meeting', 'easter', 'having', 'call', 'dancing', 'waiting', 'this', 'song', 'baby', 'raining', 'roses', 'afternoon', 'likes', 'night', 'yesterday', 'works', 'getting', 'football', 'taught', 'accident', 'hungry', 'in', 'are', 'teaches', 'rain', 'go', 'see', 'teach', 'repairing', 'on', 'twice', 'suffering', 'running', 'teacher', 'thinking', 'take', 'cook', 'because', 'us', 'do', 'sister', 'years', 'before', 'visiting', 'burning', 'her', 'basketball', 'zoo', 'ritheesh', 'tea', 'husband', 'since', 'went', 'street', 'india', 'critical', 'knew', 'that', 'my', 'they', 'by', 'girls', 'flew', 'cooks', 'sentence', 'the', 'ishwarya', 'whole', 'already', 'understood', 'always', 'weeks', 'friend', 'kabaddi', 'early', 'study', 'speak', 'read', 'friends', 'evening', 'sweet', 'writing', 'all', 'he', 'canada', 'from', 'cows', 'their', 'house', 'moment', 'week', 'past', 'which', 'many', 'seeing', 'first', 'album', 'pilot', 'turkey', 'america', 'portraits', 'recently', 'plays', 'but', 'climbing', 'sings', 'phone', 'gone', 'have', 'will', 'was', 'joseph', 'red', 'children', 'programming', 'parents', 'these', 'whom', 'navvya', 'tired', 'his', 'sing', 'letter', 'finished', 'around', 'has', 'every', 'snowing', 'today', 'mountains', 'painted', 'him', 'john', 'never', 'invloves', 'fun', 'morning', 'mountain', 'when', 'people', 'parcel', 'homework', 'letters', 'brother', 'car', 'boys', 'a', 'delicious', 'very', 'looking', 'enjoying', 'ago', 'we', 'far', 'cleaning', 'book', 'may', 'written', 'been', 'is', 'living', 'you', 'ajitesh', 'pope', 'garden', 'not', 'give', 'food', 'topper', 'married', 'tomorrow', 'no', 'gracefully', 'assignment', 'raj', 'fog', 'party', 'goats', 'heavily', 'turn', 'feeling', 'books', 'accountant', 'at', 'while', 'were', 'for', 'started', 'jacksons', 'watched', 'me', 'peacocks', 'outlet', 'movie', 'terrible', 'i', 'playing', 'saw', 'still', 'drink', 'going', 'mom', 'few', 'seen', 'picture', 'last', 'given', 'school', 'bed', 'studying', 'cup', 'fire', 'emails', 'teaching', 'severe', 'two', 'films', 'room', 'player', 'ringing', 'fed', 'nice', 'wednesday', 'as', 'be', 'well', 'neighbourhood', 'new', 'paris', 'four', 'know', 'gave', 'cold', 'acted', 'times', 'three', 'had', 'germany', 'january', 'whereabouts', 'received', 'year', 'flown', 'patient', 'constantly', 'think', 'milk', 'november', 'lately', 'next', 'opening', 'made', 'caught', 'switzerland', 'taking', 'draws', 'building', 'dad', 'down', 'climbs', 'listening', 'spending', 'it', 'ages', 'understands', 'month', 'grandfather', 'weather', 'airplane', 'of'}
# Productions :
# S -> ('NP_SG', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT', 'S1')
# S -> ('S', 'ADV')
# S -> ('NP_SG', 'PRES_PERFECT_SG', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'PAST_CONT_PL', 'S1')
# S -> ('NP_SG', 'PAST', 'S1')
# S -> ('NP_SG', 'FUTURE', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_PL', 'S1')
# S -> ('NP_PL', 'FUTURE_CONT', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'FUTURE_CONT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PRES_CONT_SG', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_CONT_PL', 'S1')
# S -> ('NP_PL', 'FUTURE', 'S1')
# S -> ('NP_PL', 'PRES_PL', 'S1')
# S -> ('NP_PL', 'PRES_CONT_PL', 'S1')
# S -> ('NP_SG', 'PAST_CONT_SG', 'S1')
# S -> ('NP_PL', 'PAST', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_CONT_SG', 'S1')
# S -> ('NP_SG', 'PRES_SG', 'S1')
# S1 -> ('NP',)
# S1 -> ('ADV',)
# NP -> ('NP_SG',)
# NP -> ('NP_PL',)
# NP -> ('PP',)
# NP -> ('NP', 'PP')
# NP_SG -> ('DET_SG', 'NOM_SG')
# NP_SG -> ('PRONOUN_SG', 'NOM_SG')
# NP_SG -> ('ADV', 'NP_SG')
# NP_SG -> ('NP_SG', 'CONJ', 'NP')
# NP_SG -> ('PROPERNOUN',)
# NP_SG -> ('PRONOUN_SG',)
# NP_SG -> ('NOM_SG',)
# NP_SG -> ('DET_BOTH', 'NOM_SG')
# NOM_SG -> ('NOUN_SG',)
# NOM_SG -> ('ADJ', 'NOUN_SG')
# NOM_SG -> ('NOM_SG', 'NOUN_SG')
# NP_PL -> ('DET_BOTH', 'NOM_PL')
# NP_PL -> ('NP_PL', 'CONJ', 'NP')
# NP_PL -> ('NOM_PL',)
# NP_PL -> ('PRONOUN_PL',)
# NP_PL -> ('PRONOUN_PL', 'NOM_PL')
# NP_PL -> ('DET_PL', 'NOM_PL')
# NP_PL -> ('ADV', 'NP_PL')
# NOM_PL -> ('NOM_PL', 'NOUN_PL')
# NOM_PL -> ('NOUN_PL',)
# NOM_PL -> ('ADJ', 'NOUN_PL')
# PP -> ('PREPOS', 'NP_SG')
# PP -> ('PREPOS', 'NP_PL')
# PAST -> ('V2',)
# PAST -> ('ADV', 'V2')
# PAST_PERFECT -> ('had', 'ADV', 'V3')
# PAST_PERFECT -> ('had', 'V3')
# PAST_CONT_SG -> ('was', 'GERUNDV')
# PAST_CONT_SG -> ('was', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'ADV', 'been', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'been', 'GERUNDV')
# PRES_SG -> ('V1_SG',)
# PRES_SG -> ('ADV', 'V1_SG')
# PRES_PL -> ('ADV', 'V1_PL')
# PRES_PL -> ('V1_PL',)
# PRES_PERFECT_SG -> ('has', 'ADV', 'V3')
# PRES_PERFECT_SG -> ('has', 'V3')
# PRES_PERFECT_PL -> ('have', 'ADV', 'V3')
# PRES_PERFECT_PL -> ('have', 'V3')
# PRES_CONT_SG -> ('is', 'ADV', 'GERUNDV')
# PRES_CONT_SG -> ('is', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'ADV', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been')
# PRES_PERFECT_CONT_PL -> ('have', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'ADV', 'been', 'GERUNDV')
# FUTURE -> ('will', 'ADV', 'V1_PL')
# FUTURE -> ('will', 'V1_PL')
# FUTURE_PERFECT -> ('will', 'have', 'V3')
# FUTURE_PERFECT -> ('will', 'have', 'ADV', 'V3')
# FUTURE_CONT -> ('will', 'be', 'GERUNDV')
# FUTURE_CONT -> ('will', 'ADV', 'be', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'been', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'ADV', 'been', 'GERUNDV')
# PRONOUN_SG -> ('him',)
# PRONOUN_SG -> ('he',)
# PRONOUN_SG -> ('my',)
# PRONOUN_SG -> ('her',)
# PRONOUN_SG -> ('she',)
# PRONOUN_SG -> ('i',)
# PRONOUN_SG -> ('his',)
# PRONOUN_SG -> ('it',)
# PRONOUN_PL -> ('you',)
# PRONOUN_PL -> ('they',)
# PRONOUN_PL -> ('their',)
# PRONOUN_PL -> ('we',)
# PRONOUN_PL -> ('us',)
# RELPR_SG -> ('which',)
# RELPR_PL -> ('whom',)
# PROPERNOUN -> ('joseph',)
# PROPERNOUN -> ('november',)
# PROPERNOUN -> ('germany',)
# PROPERNOUN -> ('ritheesh',)
# PROPERNOUN -> ('paris',)
# PROPERNOUN -> ('easter',)
# PROPERNOUN -> ('raj',)
# PROPERNOUN -> ('john',)
# PROPERNOUN -> ('navvya',)
# PROPERNOUN -> ('ishwarya',)
# PROPERNOUN -> ('canada',)
# PROPERNOUN -> ('january',)
# PROPERNOUN -> ('turkey',)
# PROPERNOUN -> ('america',)
# PROPERNOUN -> ('ajitesh',)
# PROPERNOUN -> ('wednesday',)
# PROPERNOUN -> ('switzerland',)
# PROPERNOUN -> ('may',)
# PROPERNOUN -> ('india',)
# NOUN_SG -> ('mom',)
# NOUN_SG -> ('kabaddi',)
# NOUN_SG -> ('player',)
# NOUN_SG -> ('year',)
# NOUN_SG -> ('food',)
# NOUN_SG -> ('pilot',)
# NOUN_SG -> ('basketball',)
# NOUN_SG -> ('cup',)
# NOUN_SG -> ('neighbourhood',)
# NOUN_SG -> ('teacher',)
# NOUN_SG -> ('topper',)
# NOUN_SG -> ('week',)
# NOUN_SG -> ('brother',)
# NOUN_SG -> ('party',)
# NOUN_SG -> ('fog',)
# NOUN_SG -> ('car',)
# NOUN_SG -> ('call',)
# NOUN_SG -> ('thinking',)
# NOUN_SG -> ('month',)
# NOUN_SG -> ('evening',)
# NOUN_SG -> ('school',)
# NOUN_SG -> ('song',)
# NOUN_SG -> ('book',)
# NOUN_SG -> ('house',)
# NOUN_SG -> ('programming',)
# NOUN_SG -> ('street',)
# NOUN_SG -> ('morning',)
# NOUN_SG -> ('show',)
# NOUN_SG -> ('phone',)
# NOUN_SG -> ('weekend',)
# NOUN_SG -> ('parcel',)
# NOUN_SG -> ('homework',)
# NOUN_SG -> ('pope',)
# NOUN_SG -> ('sister',)
# NOUN_SG -> ('mountain',)
# NOUN_SG -> ('weather',)
# NOUN_SG -> ('friend',)
# NOUN_SG -> ('accident',)
# NOUN_SG -> ('milk',)
# NOUN_SG -> ('room',)
# NOUN_SG -> ('album',)
# NOUN_SG -> ('zoo',)
# NOUN_SG -> ('airplane',)
# NOUN_SG -> ('me',)
# NOUN_SG -> ('airport',)
# NOUN_SG -> ('afternoon',)
# NOUN_SG -> ('tea',)
# NOUN_SG -> ('husband',)
# NOUN_SG -> ('assignment',)
# NOUN_SG -> ('accountant',)
# NOUN_SG -> ('fire',)
# NOUN_SG -> ('cold',)
# NOUN_SG -> ('picture',)
# NOUN_SG -> ('grandfather',)
# NOUN_SG -> ('night',)
# NOUN_SG -> ('outlet',)
# NOUN_SG -> ('movie',)
# NOUN_SG -> ('baby',)
# NOUN_SG -> ('letter',)
# NOUN_SG -> ('building',)
# NOUN_SG -> ('sentence',)
# NOUN_SG -> ('dad',)
# NOUN_SG -> ('football',)
# NOUN_SG -> ('bed',)
# NOUN_SG -> ('patient',)
# NOUN_SG -> ('wife',)
# NOUN_SG -> ('moment',)
# NOUN_SG -> ('garden',)
# NOUN_PL -> ('times',)
# NOUN_PL -> ('portraits',)
# NOUN_PL -> ('roses',)
# NOUN_PL -> ('peacocks',)
# NOUN_PL -> ('people',)
# NOUN_PL -> ('mountains',)
# NOUN_PL -> ('parents',)
# NOUN_PL -> ('specialists',)
# NOUN_PL -> ('letters',)
# NOUN_PL -> ('years',)
# NOUN_PL -> ('films',)
# NOUN_PL -> ('jacksons',)
# NOUN_PL -> ('books',)
# NOUN_PL -> ('cows',)
# NOUN_PL -> ('ages',)
# NOUN_PL -> ('emails',)
# NOUN_PL -> ('goats',)
# NOUN_PL -> ('girls',)
# NOUN_PL -> ('boys',)
# NOUN_PL -> ('friends',)
# NOUN_PL -> ('children',)
# NOUN_PL -> ('weeks',)
# DET_SG -> ('a',)
# DET_SG -> ('this',)
# DET_SG -> ('an',)
# DET_SG -> ('that',)
# DET_PL -> ('all',)
# DET_PL -> ('many',)
# DET_PL -> ('no',)
# DET_PL -> ('these',)
# DET_BOTH -> ('the',)
# CONJ -> ('while',)
# CONJ -> ('and',)
# CONJ -> ('because',)
# CONJ -> ('but',)
# ADJ -> ('critical',)
# ADJ -> ('few',)
# ADJ -> ('first',)
# ADJ -> ('three',)
# ADJ -> ('four',)
# ADJ -> ('red',)
# ADJ -> ('last',)
# ADJ -> ('fun',)
# ADJ -> ('delicious',)
# ADJ -> ('two',)
# ADJ -> ('since',)
# ADJ -> ('severe',)
# ADJ -> ('new',)
# ADJ -> ('hungry',)
# ADJ -> ('every',)
# ADJ -> ('nice',)
# ADJ -> ('sweet',)
# ADJ -> ('terrible',)
# ADJ -> ('whole',)
# ADV -> ('early',)
# ADV -> ('lately',)
# ADV -> ('tomorrow',)
# ADV -> ('ago',)
# ADV -> ('gracefully',)
# ADV -> ('heavily',)
# ADV -> ('yesterday',)
# ADV -> ('not',)
# ADV -> ('constantly',)
# ADV -> ('twice',)
# ADV -> ('before',)
# ADV -> ('whereabouts',)
# ADV -> ('never',)
# ADV -> ('when',)
# ADV -> ('well',)
# ADV -> ('already',)
# ADV -> ('still',)
# ADV -> ('always',)
# ADV -> ('next',)
# ADV -> ('today',)
# ADV -> ('past',)
# ADV -> ('recently',)
# ADV -> ('very',)
# PREPOS -> ('at',)
# PREPOS -> ('as',)
# PREPOS -> ('for',)
# PREPOS -> ('by',)
# PREPOS -> ('of',)
# PREPOS -> ('to',)
# PREPOS -> ('down',)
# PREPOS -> ('from',)
# PREPOS -> ('in',)
# PREPOS -> ('far',)
# PREPOS -> ('around',)
# PREPOS -> ('on',)
# V1_SG -> ('teaches',)
# V1_SG -> ('invloves',)
# V1_SG -> ('am',)
# V1_SG -> ('plays',)
# V1_SG -> ('be',)
# V1_SG -> ('works',)
# V1_SG -> ('understands',)
# V1_SG -> ('cooks',)
# V1_SG -> ('sings',)
# V1_SG -> ('likes',)
# V1_SG -> ('is',)
# V1_SG -> ('draws',)
# V1_SG -> ('know',)
# V1_SG -> ('climbs',)
# V1_PL -> ('rain',)
# V1_PL -> ('think',)
# V1_PL -> ('see',)
# V1_PL -> ('teach',)
# V1_PL -> ('give',)
# V1_PL -> ('study',)
# V1_PL -> ('drink',)
# V1_PL -> ('take',)
# V1_PL -> ('cook',)
# V1_PL -> ('turn',)
# V1_PL -> ('sing',)
# V1_PL -> ('are',)
# V1_PL -> ('do',)
# V1_PL -> ('go',)
# V1_PL -> ('speak',)
# GERUNDV -> ('ringing',)
# GERUNDV -> ('meeting',)
# GERUNDV -> ('snowing',)
# GERUNDV -> ('repairing',)
# GERUNDV -> ('dancing',)
# GERUNDV -> ('having',)
# GERUNDV -> ('suffering',)
# GERUNDV -> ('burning',)
# GERUNDV -> ('teaching',)
# GERUNDV -> ('dating',)
# GERUNDV -> ('running',)
# GERUNDV -> ('writing',)
# GERUNDV -> ('looking',)
# GERUNDV -> ('climbing',)
# GERUNDV -> ('playing',)
# GERUNDV -> ('listening',)
# GERUNDV -> ('raining',)
# GERUNDV -> ('enjoying',)
# GERUNDV -> ('cleaning',)
# GERUNDV -> ('waiting',)
# GERUNDV -> ('living',)
# GERUNDV -> ('feeling',)
# GERUNDV -> ('opening',)
# GERUNDV -> ('getting',)
# GERUNDV -> ('taking',)
# GERUNDV -> ('studying',)
# GERUNDV -> ('spending',)
# GERUNDV -> ('going',)
# GERUNDV -> ('seeing',)
# GERUNDV -> ('visiting',)
# V2 -> ('knew',)
# V2 -> ('read',)
# V2 -> ('received',)
# V2 -> ('tired',)
# V2 -> ('flew',)
# V2 -> ('understood',)
# V2 -> ('gave',)
# V2 -> ('were',)
# V2 -> ('went',)
# V2 -> ('did',)
# V2 -> ('was',)
# V2 -> ('made',)
# V2 -> ('would',)
# V2 -> ('married',)
# V2 -> ('caught',)
# V2 -> ('drink',)
# V2 -> ('started',)
# V2 -> ('saw',)
# V2 -> ('taught',)
# V3 -> ('met',)
# V3 -> ('made',)
# V3 -> ('watched',)
# V3 -> ('given',)
# V3 -> ('painted',)
# V3 -> ('flown',)
# V3 -> ('seen',)
# V3 -> ('written',)
# V3 -> ('done',)
# V3 -> ('gone',)
# V3 -> ('finished',)
# V3 -> ('fed',)
# V3 -> ('acted',)

# %% [markdown]
# ## Module 3 - Construction of SLR(1) Parser Table
#
# Input : English Grammar Object
#
# Output : SLR(1) Parsing table
#
#
# -> First and Follow
#
# -> Canonical collection of LR(0) items
#
# -> Building Parser table

# %%
# Generating first and follow sets

def first_follow(G) :
  def union(set1, set2):
    set1len = len(set1)
    set1 |= set2
    return set1len != len(set1)

  # initialising the data structures to store and first and follow values
  first = { symbol: set() for symbol in G.symbols }
  follow = { symbol: set() for symbol in G.symbols }

  for symbol in G.symbols :
    if symbol in G.terminals :
      first[symbol].add(symbol)
  
  follow[G.startSymbol].add('$')

  while True :
    updated = False

    for head, bodies in G.grammar.items() :
      for body in bodies :
        for symbol in body :
          if symbol != '^':
            updated |= union(first[head], first[symbol] - set('^'))
            if '^' not in first[symbol] :
              break
            else :
              updated |= union(first[head], set('^'))
        aux = follow[head]
        for symbol in reversed(body) :
          if symbol == '^':
            continue
          if symbol in follow:
            updated |= union(follow[symbol], aux - set('^'))
          if '^' in first[symbol] :
            aux = aux | first[symbol]
          else :
            aux = first[symbol]
    if not updated:
      return first, follow

# %%
# Construction of LR(0) items

# Computation of set of items constructed from I
# I - set of items for G
def CLOSURE(aug_G, I):
  J = I
  
  while True :
    item_len = len(J)
    for head, bodies in J.copy().items() :
      for body in bodies.copy():
        if '.' in body[:-1]:
          dot_pos = body.index('.')
          symbol_after_dot = body[dot_pos + 1]
          if symbol_after_dot in aug_G.nonterminals :
            for G_body in aug_G.grammar[symbol_after_dot]:
              if G_body == tuple('^'):
                J.setdefault(symbol_after_dot, set()).add(set('.'))
              else :
                J.setdefault(symbol_after_dot, set()).add(('.',) + G_body)
    if item_len == len(J):
      return J

# GOTO(I, X) defined to be the closure of the set of all items [A -> aX.b] such that [A -> a.Xb] is in I
# I - set of items
# X - grammar symbol
def GOTO(aug_G, I, X):
  goto = {}

  for head, bodies in I.items() :
    for body in bodies :
      if '.' in body[:-1]:
        dot_pos = body.index('.')
        if body[dot_pos + 1] == X :
          replaced_dot_body = body[ : dot_pos] + (X, '.') + body[dot_pos + 2: ]
          for C_head, C_bodies in CLOSURE(aug_G, {head: {replaced_dot_body}}).items():
            goto.setdefault(C_head, set()).update(C_bodies)
  
  return goto

# Construction of canonical collection of sets of LR(0) items for G'
def items(aug_G):
  C = [CLOSURE(aug_G, {aug_G.startSymbol : {('.', aug_G.startSymbol[:-1])}})]

  while True:
    item_len = len(C)
    for I in C.copy() :
      for X in aug_G.symbols:
        goto = GOTO(aug_G, I, X)
        if (len(goto) > 0) and goto not in C:
          C.append(goto)
    if item_len == len(C) :
      return C

# %%
# Construction of SLR(1) Parsing table

class SLRParser:
  def __init__(self, G):
    self.aug_G = Grammar([f"{G.startSymbol}' -> {G.startSymbol}"] + G.input)
    self.max_aug_G_len = len(max(self.aug_G.grammar, key=len))

    self.G_indexed = []
    for head, bodies in self.aug_G.grammar.items():
      for body in bodies:
        self.G_indexed.append([head, body])
    
    self.first, self.follow = first_follow(self.aug_G)

    self.C = items(self.aug_G)
    
    self.action = list(self.aug_G.terminals) + ['$']
    self.goto = []
    for nonterminal in self.aug_G.nonterminals :
      if nonterminal != self.aug_G.startSymbol :
        self.goto.append(nonterminal)
    
    self.parse_table_symbols = self.action + self.goto
    self.parse_table = self.construct_table()
  
  def construct_table(self):
    # Step 1 - Construct C
    # Step 2 - parsing actions for state i are determined
    parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

    for i, I in enumerate(self.C) :
      for head, bodies in I.items() :
        for body in bodies :
          if '.' in body[:-1] : # Case 2a
            dot_pos = body.index('.')
            symbol_after_dot = body[dot_pos + 1]

            if symbol_after_dot in self.aug_G.terminals :
              s = f's{self.C.index(GOTO(self.aug_G, I, symbol_after_dot))}'
              if s not in parse_table[i][symbol_after_dot]:
                if 'r' in parse_table[i][symbol_after_dot] :
                  parse_table[i][symbol_after_dot] += '/'
                parse_table[i][symbol_after_dot] += s
          
          elif body[-1] == '.' and head != self.aug_G.startSymbol : # Case 2b
            for j, (G_head, G_body) in enumerate(self.G_indexed) :
              if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                for f in self.follow[head] :
                  if parse_table[i][f] :
                    parse_table[i][f] += '/'
                  parse_table[i][f] += f'r{j}'

                break

          else : # Case 2c
            parse_table[i]['$'] = 'acc'
      
      # Step 3 - Goto transistions for all nonterminals are constructed
      for A in self.aug_G.nonterminals :
        j = GOTO(self.aug_G, I, A)
        if j in self.C :
          parse_table[i][A] = self.C.index(j)

    return parse_table

  def __str__ (self) :
    def fprint(text, variable) :
      print(f'{text:>12}: {", ".join(variable)}')
    def print_line() :
      print(f'+{("-" * width + "+") * (len(list(self.aug_G.symbols) + ["$"]))}')
    def symbols_width(symbols) :
      return (width + 1) * len(symbols) - 1

    print("Augmented Grammar : ")
    for i, (head, body) in enumerate(self.G_indexed):
      print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_aug_G_len}} -> {" ".join(body)}')
    print()
    fprint('TERMINALS', self.aug_G.terminals)
    fprint('NONTERMINALS', self.aug_G.nonterminals)
    fprint('SYMBOLS', self.aug_G.symbols)

    print('\nFIRST:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.first[head])} }}')

    print('\nFOLLOW:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.follow[head])} }}')

    width = max(len(c) for c in {'ACTION'} | self.aug_G.symbols) + 2
    for r in range(len(self.C)):
      max_len = max(len(str(c)) for c in self.parse_table[r].values())

      if width < max_len + 2:
        width = max_len + 2

    print('\nPARSING TABLE:')
    print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
    print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
    print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
    print(f'|{"":^{width}}|', end=' ')

    for symbol in self.parse_table_symbols:
      print(f'{symbol:^{width - 1}}|', end=' ')

    print()
    print_line()

    for r in range(len(self.C)):
      print(f'|{r:^{width}}|', end=' ')

      for c in self.parse_table_symbols:
        print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

      print()

    print_line()
    print()
    return ""

# %%
slr = SLRParser(G)
print(slr)
# Out:
# Augmented Grammar :
#   0:                   S' -> S
#   1:                    S -> NP_SG FUTURE_PERFECT S1
#   2:                    S -> NP_PL FUTURE_PERFECT S1
#   3:                    S -> S ADV
#   4:                    S -> NP_SG PRES_PERFECT_SG S1
#   5:                    S -> NP_SG PAST_PERFECT_CONT S1
#   6:                    S -> NP_PL FUTURE_PERFECT_CONT S1
#   7:                    S -> NP_PL PAST_CONT_PL S1
#   8:                    S -> NP_SG PAST S1
#   9:                    S -> NP_SG FUTURE S1
#  10:                    S -> NP_SG PAST_PERFECT S1
#  11:                    S -> NP_PL PAST_PERFECT S1
#  12:                    S -> NP_PL PRES_PERFECT_PL S1
#  13:                    S -> NP_PL FUTURE_CONT S1
#  14:                    S -> NP_SG FUTURE_PERFECT_CONT S1
#  15:                    S -> NP_SG FUTURE_CONT S1
#  16:                    S -> NP_PL PAST_PERFECT_CONT S1
#  17:                    S -> NP_SG PRES_CONT_SG S1
#  18:                    S -> NP_PL PRES_PERFECT_CONT_PL S1
#  19:                    S -> NP_PL FUTURE S1
#  20:                    S -> NP_PL PRES_PL S1
#  21:                    S -> NP_PL PRES_CONT_PL S1
#  22:                    S -> NP_SG PAST_CONT_SG S1
#  23:                    S -> NP_PL PAST S1
#  24:                    S -> NP_SG PRES_PERFECT_CONT_SG S1
#  25:                    S -> NP_SG PRES_SG S1
#  26:                   S1 -> NP
#  27:                   S1 -> ADV
#  28:                   NP -> NP_SG
#  29:                   NP -> NP_PL
#  30:                   NP -> PP
#  31:                   NP -> NP PP
#  32:                NP_SG -> DET_SG NOM_SG
#  33:                NP_SG -> PRONOUN_SG NOM_SG
#  34:                NP_SG -> ADV NP_SG
#  35:                NP_SG -> NP_SG CONJ NP
#  36:                NP_SG -> PROPERNOUN
#  37:                NP_SG -> PRONOUN_SG
#  38:                NP_SG -> NOM_SG
#  39:                NP_SG -> DET_BOTH NOM_SG
#  40:               NOM_SG -> NOUN_SG
#  41:               NOM_SG -> ADJ NOUN_SG
#  42:               NOM_SG -> NOM_SG NOUN_SG
#  43:                NP_PL -> DET_BOTH NOM_PL
#  44:                NP_PL -> NP_PL CONJ NP
#  45:                NP_PL -> NOM_PL
#  46:                NP_PL -> PRONOUN_PL
#  47:                NP_PL -> PRONOUN_PL NOM_PL
#  48:                NP_PL -> DET_PL NOM_PL
#  49:                NP_PL -> ADV NP_PL
#  50:               NOM_PL -> NOM_PL NOUN_PL
#  51:               NOM_PL -> NOUN_PL
#  52:               NOM_PL -> ADJ NOUN_PL
#  53:                   PP -> PREPOS NP_SG
#  54:                   PP -> PREPOS NP_PL
#  55:                 PAST -> V2
#  56:                 PAST -> ADV V2
#  57:         PAST_PERFECT -> had ADV V3
#  58:         PAST_PERFECT -> had V3
#  59:         PAST_CONT_SG -> was GERUNDV
#  60:         PAST_CONT_SG -> was ADV GERUNDV
#  61:         PAST_CONT_PL -> were ADV GERUNDV
#  62:         PAST_CONT_PL -> were GERUNDV
#  63:    PAST_PERFECT_CONT -> had ADV been GERUNDV
#  64:    PAST_PERFECT_CONT -> had been GERUNDV
#  65:              PRES_SG -> V1_SG
#  66:              PRES_SG -> ADV V1_SG
#  67:              PRES_PL -> ADV V1_PL
#  68:              PRES_PL -> V1_PL
#  69:      PRES_PERFECT_SG -> has ADV V3
#  70:      PRES_PERFECT_SG -> has V3
#  71:      PRES_PERFECT_PL -> have ADV V3
#  72:      PRES_PERFECT_PL -> have V3
#  73:         PRES_CONT_SG -> is ADV GERUNDV
#  74:         PRES_CONT_SG -> is GERUNDV
#  75:         PRES_CONT_PL -> are ADV GERUNDV
#  76:         PRES_CONT_PL -> are GERUNDV
#  77: PRES_PERFECT_CONT_SG -> has been GERUNDV
#  78: PRES_PERFECT_CONT_SG -> has ADV been GERUNDV
#  79: PRES_PERFECT_CONT_SG -> has been
#  80: PRES_PERFECT_CONT_SG -> has ADV been
#  81: PRES_PERFECT_CONT_PL -> have been GERUNDV
#  82: PRES_PERFECT_CONT_PL -> have ADV been GERUNDV
#  83:               FUTURE -> will ADV V1_PL
#  84:               FUTURE -> will V1_PL
#  85:       FUTURE_PERFECT -> will have V3
#  86:       FUTURE_PERFECT -> will have ADV V3
#  87:          FUTURE_CONT -> will be GERUNDV
#  88:          FUTURE_CONT -> will ADV be GERUNDV
#  89:  FUTURE_PERFECT_CONT -> will have been GERUNDV
#  90:  FUTURE_PERFECT_CONT -> will have ADV been GERUNDV
#  91:           PRONOUN_SG -> him
#  92:           PRONOUN_SG -> he
#  93:           PRONOUN_SG -> my
#  94:           PRONOUN_SG -> her
#  95:           PRONOUN_SG -> she
#  96:           PRONOUN_SG -> i
#  97:           PRONOUN_SG -> his
#  98:           PRONOUN_SG -> it
#  99:           PRONOUN_PL -> you
# 100:           PRONOUN_PL -> they
# 101:           PRONOUN_PL -> their
# 102:           PRONOUN_PL -> we
# 103:           PRONOUN_PL -> us
# 104:             RELPR_SG -> which
# 105:             RELPR_PL -> whom
# 106:           PROPERNOUN -> joseph
# 107:           PROPERNOUN -> november
# 108:           PROPERNOUN -> germany
# 109:           PROPERNOUN -> ritheesh
# 110:           PROPERNOUN -> paris
# 111:           PROPERNOUN -> easter
# 112:           PROPERNOUN -> raj
# 113:           PROPERNOUN -> john
# 114:           PROPERNOUN -> navvya
# 115:           PROPERNOUN -> ishwarya
# 116:           PROPERNOUN -> canada
# 117:           PROPERNOUN -> january
# 118:           PROPERNOUN -> turkey
# 119:           PROPERNOUN -> america
# 120:           PROPERNOUN -> ajitesh
# 121:           PROPERNOUN -> wednesday
# 122:           PROPERNOUN -> switzerland
# 123:           PROPERNOUN -> may
# 124:           PROPERNOUN -> india
# 125:              NOUN_SG -> mom
# 126:              NOUN_SG -> kabaddi
# 127:              NOUN_SG -> player
# 128:              NOUN_SG -> year
# 129:              NOUN_SG -> food
# 130:              NOUN_SG -> pilot
# 131:              NOUN_SG -> basketball
# 132:              NOUN_SG -> cup
# 133:              NOUN_SG -> neighbourhood
# 134:              NOUN_SG -> teacher
# 135:              NOUN_SG -> topper
# 136:              NOUN_SG -> week
# 137:              NOUN_SG -> brother
# 138:              NOUN_SG -> party
# 139:              NOUN_SG -> fog
# 140:              NOUN_SG -> car
# 141:              NOUN_SG -> call
# 142:              NOUN_SG -> thinking
# 143:              NOUN_SG -> month
# 144:              NOUN_SG -> evening
# 145:              NOUN_SG -> school
# 146:              NOUN_SG -> song
# 147:              NOUN_SG -> book
# 148:              NOUN_SG -> house
# 149:              NOUN_SG -> programming
# 150:              NOUN_SG -> street
# 151:              NOUN_SG -> morning
# 152:              NOUN_SG -> show
# 153:              NOUN_SG -> phone
# 154:              NOUN_SG -> weekend
# 155:              NOUN_SG -> parcel
# 156:              NOUN_SG -> homework
# 157:              NOUN_SG -> pope
# 158:              NOUN_SG -> sister
# 159:              NOUN_SG -> mountain
# 160:              NOUN_SG -> weather
# 161:              NOUN_SG -> friend
# 162:              NOUN_SG -> accident
# 163:              NOUN_SG -> milk
# 164:              NOUN_SG -> room
# 165:              NOUN_SG -> album
# 166:              NOUN_SG -> zoo
# 167:              NOUN_SG -> airplane
# 168:              NOUN_SG -> me
# 169:              NOUN_SG -> airport
# 170:              NOUN_SG -> afternoon
# 171:              NOUN_SG -> tea
# 172:              NOUN_SG -> husband
# 173:              NOUN_SG -> assignment
# 174:              NOUN_SG -> accountant
# 175:              NOUN_SG -> fire
# 176:              NOUN_SG -> cold
# 177:              NOUN_SG -> picture
# 178:              NOUN_SG -> grandfather
# 179:              NOUN_SG -> night
# 180:              NOUN_SG -> outlet
# 181:              NOUN_SG -> movie
# 182:              NOUN_SG -> baby
# 183:              NOUN_SG -> letter
# 184:              NOUN_SG -> building
# 185:              NOUN_SG -> sentence
# 186:              NOUN_SG -> dad
# 187:              NOUN_SG -> football
# 188:              NOUN_SG -> bed
# 189:              NOUN_SG -> patient
# 190:              NOUN_SG -> wife
# 191:              NOUN_SG -> moment
# 192:              NOUN_SG -> garden
# 193:              NOUN_PL -> times
# 194:              NOUN_PL -> portraits
# 195:              NOUN_PL -> roses
# 196:              NOUN_PL -> peacocks
# 197:              NOUN_PL -> people
# 198:              NOUN_PL -> mountains
# 199:              NOUN_PL -> parents
# 200:              NOUN_PL -> specialists
# 201:              NOUN_PL -> letters
# 202:              NOUN_PL -> years
# 203:              NOUN_PL -> films
# 204:              NOUN_PL -> jacksons
# 205:              NOUN_PL -> books
# 206:              NOUN_PL -> cows
# 207:              NOUN_PL -> ages
# 208:              NOUN_PL -> emails
# 209:              NOUN_PL -> goats
# 210:              NOUN_PL -> girls
# 211:              NOUN_PL -> boys
# 212:              NOUN_PL -> friends
# 213:              NOUN_PL -> children
# 214:              NOUN_PL -> weeks
# 215:               DET_SG -> a
# 216:               DET_SG -> this
# 217:               DET_SG -> an
# 218:               DET_SG -> that
# 219:               DET_PL -> all
# 220:               DET_PL -> many
# 221:               DET_PL -> no
# 222:               DET_PL -> these
# 223:             DET_BOTH -> the
# 224:                 CONJ -> while
# 225:                 CONJ -> and
# 226:                 CONJ -> because
# 227:                 CONJ -> but
# 228:                  ADJ -> critical
# 229:                  ADJ -> few
# 230:                  ADJ -> first
# 231:                  ADJ -> three
# 232:                  ADJ -> four
# 233:                  ADJ -> red
# 234:                  ADJ -> last
# 235:                  ADJ -> fun
# 236:                  ADJ -> delicious
# 237:                  ADJ -> two
# 238:                  ADJ -> since
# 239:                  ADJ -> severe
# 240:                  ADJ -> new
# 241:                  ADJ -> hungry
# 242:                  ADJ -> every
# 243:                  ADJ -> nice
# 244:                  ADJ -> sweet
# 245:                  ADJ -> terrible
# 246:                  ADJ -> whole
# 247:                  ADV -> early
# 248:                  ADV -> lately
# 249:                  ADV -> tomorrow
# 250:                  ADV -> ago
# 251:                  ADV -> gracefully
# 252:                  ADV -> heavily
# 253:                  ADV -> yesterday
# 254:                  ADV -> not
# 255:                  ADV -> constantly
# 256:                  ADV -> twice
# 257:                  ADV -> before
# 258:                  ADV -> whereabouts
# 259:                  ADV -> never
# 260:                  ADV -> when
# 261:                  ADV -> well
# 262:                  ADV -> already
# 263:                  ADV -> still
# 264:                  ADV -> always
# 265:                  ADV -> next
# 266:                  ADV -> today
# 267:                  ADV -> past
# 268:                  ADV -> recently
# 269:                  ADV -> very
# 270:               PREPOS -> at
# 271:               PREPOS -> as
# 272:               PREPOS -> for
# 273:               PREPOS -> by
# 274:               PREPOS -> of
# 275:               PREPOS -> to
# 276:               PREPOS -> down
# 277:               PREPOS -> from
# 278:               PREPOS -> in
# 279:               PREPOS -> far
# 280:               PREPOS -> around
# 281:               PREPOS -> on
# 282:                V1_SG -> teaches
# 283:                V1_SG -> invloves
# 284:                V1_SG -> am
# 285:                V1_SG -> plays
# 286:                V1_SG -> be
# 287:                V1_SG -> works
# 288:                V1_SG -> understands
# 289:                V1_SG -> cooks
# 290:                V1_SG -> sings
# 291:                V1_SG -> likes
# 292:                V1_SG -> is
# 293:                V1_SG -> draws
# 294:                V1_SG -> know
# 295:                V1_SG -> climbs
# 296:                V1_PL -> rain
# 297:                V1_PL -> think
# 298:                V1_PL -> see
# 299:                V1_PL -> teach
# 300:                V1_PL -> give
# 301:                V1_PL -> study
# 302:                V1_PL -> drink
# 303:                V1_PL -> take
# 304:                V1_PL -> cook
# 305:                V1_PL -> turn
# 306:                V1_PL -> sing
# 307:                V1_PL -> are
# 308:                V1_PL -> do
# 309:                V1_PL -> go
# 310:                V1_PL -> speak
# 311:              GERUNDV -> ringing
# 312:              GERUNDV -> meeting
# 313:              GERUNDV -> snowing
# 314:              GERUNDV -> repairing
# 315:              GERUNDV -> dancing
# 316:              GERUNDV -> having
# 317:              GERUNDV -> suffering
# 318:              GERUNDV -> burning
# 319:              GERUNDV -> teaching
# 320:              GERUNDV -> dating
# 321:              GERUNDV -> running
# 322:              GERUNDV -> writing
# 323:              GERUNDV -> looking
# 324:              GERUNDV -> climbing
# 325:              GERUNDV -> playing
# 326:              GERUNDV -> listening
# 327:              GERUNDV -> raining
# 328:              GERUNDV -> enjoying
# 329:              GERUNDV -> cleaning
# 330:              GERUNDV -> waiting
# 331:              GERUNDV -> living
# 332:              GERUNDV -> feeling
# 333:              GERUNDV -> opening
# 334:              GERUNDV -> getting
# 335:              GERUNDV -> taking
# 336:              GERUNDV -> studying
# 337:              GERUNDV -> spending
# 338:              GERUNDV -> going
# 339:              GERUNDV -> seeing
# 340:              GERUNDV -> visiting
# 341:                   V2 -> knew
# 342:                   V2 -> read
# 343:                   V2 -> received
# 344:                   V2 -> tired
# 345:                   V2 -> flew
# 346:                   V2 -> understood
# 347:                   V2 -> gave
# 348:                   V2 -> were
# 349:                   V2 -> went
# 350:                   V2 -> did
# 351:                   V2 -> was
# 352:                   V2 -> made
# 353:                   V2 -> would
# 354:                   V2 -> married
# 355:                   V2 -> caught
# 356:                   V2 -> drink
# 357:                   V2 -> started
# 358:                   V2 -> saw
# 359:                   V2 -> taught
# 360:                   V3 -> met
# 361:                   V3 -> made
# 362:                   V3 -> watched
# 363:                   V3 -> given
# 364:                   V3 -> painted
# 365:                   V3 -> flown
# 366:                   V3 -> seen
# 367:                   V3 -> written
# 368:                   V3 -> done
# 369:                   V3 -> gone
# 370:                   V3 -> finished
# 371:                   V3 -> fed
# 372:                   V3 -> acted
#
#    TERMINALS: would, and, she, show, weekend, did, an, airport, dating, to, wife, specialists, am, met, done, meeting, easter, having, call, dancing, waiting, this, song, baby, raining, roses, afternoon, likes, night, yesterday, works, getting, football, taught, accident, hungry, in, are, teaches, rain, go, see, teach, repairing, on, twice, suffering, running, teacher, thinking, take, cook, because, us, do, sister, years, before, visiting, burning, her, basketball, zoo, ritheesh, tea, husband, since, went, street, india, critical, knew, that, my, they, by, girls, flew, cooks, sentence, the, ishwarya, whole, already, understood, always, weeks, friend, kabaddi, early, study, speak, read, friends, evening, sweet, writing, all, he, canada, from, cows, their, house, moment, week, past, which, many, seeing, first, album, pilot, turkey, america, portraits, recently, plays, but, climbing, sings, phone, gone, have, will, was, joseph, red, children, programming, parents, these, whom, navvya, tired, his, sing, letter, finished, around, has, every, snowing, today, mountains, painted, him, john, never, invloves, fun, morning, mountain, when, people, parcel, homework, letters, brother, car, boys, a, delicious, very, looking, enjoying, ago, we, far, cleaning, book, may, written, been, is, living, you, ajitesh, pope, garden, not, give, food, topper, married, tomorrow, no, gracefully, assignment, raj, fog, party, goats, heavily, turn, feeling, books, accountant, at, while, were, for, started, jacksons, watched, me, peacocks, outlet, movie, terrible, i, playing, saw, still, drink, going, mom, few, seen, picture, last, given, school, bed, studying, cup, fire, emails, teaching, severe, two, films, room, player, ringing, fed, nice, wednesday, as, be, well, neighbourhood, new, paris, four, know, gave, cold, acted, times, three, had, germany, january, whereabouts, received, year, flown, patient, constantly, think, milk, november, lately, next, opening, made, caught, switzerland, taking, draws, building, dad, down, climbs, listening, spending, it, ages, understands, month, grandfather, weather, airplane, of
# NONTERMINALS: FUTURE_PERFECT, NOUN_PL, PROPERNOUN, V2, V1_SG, PRONOUN_SG, FUTURE_PERFECT_CONT, DET_SG, RELPR_SG, CONJ, RELPR_PL, S, PAST_PERFECT_CONT, PP, NOUN_SG, V1_PL, PAST_CONT_PL, DET_PL, FUTURE_CONT, PRES_PERFECT_SG, ADV, PRES_CONT_SG, PRES_PERFECT_CONT_PL, PRES_PERFECT_CONT_SG, DET_BOTH, PRES_SG, PAST_PERFECT, NP_SG, NP_PL, PRES_CONT_PL, NP, S', ADJ, PAST, FUTURE, PAST_CONT_SG, PREPOS, S1, V3, NOM_PL, NOM_SG, PRONOUN_PL, PRES_PL, PRES_PERFECT_PL, GERUNDV
#      SYMBOLS: would, she, did, weekend, airport, dating, to, met, specialists, meeting, having, dancing, DET_SG, waiting, this, song, raining, S, likes, works, V1_PL, PRES_PERFECT_SG, accident, in, rain, see, teach, on, twice, running, take, thinking, cook, burning, NP_PL, zoo, PAST_CONT_SG, PREPOS, ritheesh, tea, husband, since, critical, knew, that, my, by, flew, girls, ishwarya, understood, weeks, kabaddi, early, read, evening, sweet, writing, CONJ, he, canada, cows, their, house, moment, week, past, which, many, portraits, america, plays, but, climbing, sings, phone, will, was, red, S', parents, these, FUTURE, navvya, sing, has, today, painted, john, never, invloves, NOUN_PL, mountain, when, people, parcel, PRONOUN_SG, car, boys, delicious, looking, enjoying, ago, far, NOUN_SG, book, may, written, FUTURE_CONT, is, you, ajitesh, pope, garden, give, PRES_PERFECT_CONT_SG, married, PRES_SG, no, fog, party, goats, heavily, turn, books, at, while, NP, started, jacksons, peacocks, outlet, movie, i, drink, going, PRES_PERFECT_PL, picture, given, school, fire, emails, teaching, room, player, ringing, fed, nice, wednesday, PAST_CONT_PL, DET_PL, acted, PRES_PERFECT_CONT_PL, times, three, had, germany, whereabouts, year, patient, november, lately, next, opening, made, caught, down, NOM_SG, climbs, listening, it, understands, weather, airplane, and, show, an, done, wife, am, easter, call, baby, roses, afternoon, PAST_PERFECT_CONT, night, yesterday, getting, football, taught, hungry, repairing, are, teaches, go, suffering, teacher, DET_BOTH, because, us, do, sister, years, NP_SG, before, visiting, her, basketball, S1, went, street, india, they, cooks, sentence, the, whole, already, always, V2, V1_SG, friend, FUTURE_PERFECT_CONT, speak, study, friends, all, RELPR_PL, PP, from, seeing, first, album, pilot, turkey, recently, PAST_PERFECT, gone, have, joseph, children, programming, whom, tired, his, V3, letter, finished, around, snowing, every, mountains, him, fun, morning, homework, letters, brother, a, RELPR_SG, very, we, cleaning, been, ADV, living, not, food, topper, tomorrow, gracefully, assignment, raj, feeling, accountant, were, for, watched, me, terrible, playing, saw, still, PRONOUN_PL, of, mom, few, seen, FUTURE_PERFECT, last, bed, studying, cup, PROPERNOUN, two, films, as, be, well, neighbourhood, new, paris, PRES_CONT_SG, four, know, gave, cold, received, january, flown, constantly, think, milk, PRES_CONT_PL, switzerland, ADJ, taking, PAST, draws, NOM_PL, building, dad, spending, ages, month, grandfather, PRES_PL, severe, GERUNDV
#
# FIRST:
#                   S' = { she, weekend, airport, specialists, this, song, accident, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, every, mountains, him, fun, morning, homework, letters, brother, a, very, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, me, terrible, still, mom, few, last, bed, cup, two, films, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe }
#                    S = { she, weekend, airport, specialists, this, song, accident, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, every, mountains, him, fun, morning, homework, letters, brother, a, very, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, me, terrible, still, mom, few, last, bed, cup, two, films, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe }
#                   S1 = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#                   NP = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, a, very, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#                NP_SG = { she, show, weekend, an, airport, wife, easter, call, this, song, baby, afternoon, night, yesterday, football, accident, hungry, twice, teacher, thinking, sister, before, her, zoo, basketball, ritheesh, since, tea, husband, street, india, critical, that, my, the, sentence, already, ishwarya, whole, always, friend, early, kabaddi, evening, sweet, he, airplane, canada, house, moment, week, past, first, album, pilot, america, turkey, recently, phone, joseph, red, programming, navvya, his, letter, every, today, him, john, never, fun, morning, mountain, when, parcel, homework, brother, car, a, very, delicious, ago, book, may, ajitesh, not, pope, garden, food, topper, tomorrow, gracefully, assignment, heavily, raj, party, fog, accountant, me, outlet, movie, terrible, i, still, mom, few, picture, last, school, bed, cup, fire, two, room, player, nice, wednesday, well, neighbourhood, new, paris, four, cold, three, whereabouts, germany, january, year, patient, constantly, milk, lately, november, next, switzerland, building, dad, it, month, grandfather, weather, severe }
#               NOM_SG = { show, weekend, airport, wife, call, song, baby, afternoon, night, football, accident, hungry, teacher, thinking, sister, zoo, basketball, since, tea, husband, street, critical, sentence, whole, friend, kabaddi, evening, sweet, airplane, house, moment, week, first, album, pilot, phone, red, programming, letter, every, fun, morning, mountain, parcel, homework, brother, car, delicious, book, pope, garden, food, topper, assignment, party, fog, accountant, me, outlet, movie, terrible, mom, few, picture, last, school, bed, cup, fire, two, room, player, nice, neighbourhood, new, four, cold, three, year, patient, milk, building, dad, month, grandfather, weather, severe }
#                NP_PL = { fun, when, people, specialists, letters, boys, very, delicious, ago, roses, we, yesterday, hungry, you, not, twice, tomorrow, no, gracefully, us, heavily, goats, years, before, books, jacksons, since, peacocks, terrible, critical, still, few, they, girls, last, the, whole, already, always, emails, two, weeks, films, early, friends, nice, sweet, all, well, new, cows, their, four, past, many, times, whereabouts, first, portraits, three, recently, constantly, lately, next, red, children, parents, these, every, today, ages, mountains, never, severe }
#               NOM_PL = { fun, people, specialists, letters, boys, delicious, roses, hungry, goats, years, books, jacksons, since, peacocks, terrible, critical, few, girls, last, whole, emails, two, weeks, films, friends, nice, sweet, new, cows, four, times, first, portraits, three, red, children, parents, every, ages, mountains, severe }
#                   PP = { to, at, by, as, for, from, far, down, around, in, on, of }
#                 PAST = { would, did, when, already, understood, always, early, read, very, well, ago, yesterday, taught, gave, past, not, twice, whereabouts, received, married, recently, tomorrow, gracefully, heavily, constantly, before, lately, was, next, made, were, caught, started, tired, went, saw, knew, still, today, drink, never, flew }
#         PAST_PERFECT = { had }
#         PAST_CONT_SG = { was }
#         PAST_CONT_PL = { were }
#    PAST_PERFECT_CONT = { had }
#              PRES_SG = { invloves, cooks, when, already, always, am, early, very, be, well, ago, likes, works, yesterday, is, teaches, know, past, not, twice, whereabouts, plays, recently, tomorrow, gracefully, heavily, sings, constantly, before, lately, next, draws, climbs, still, understands, today, never }
#              PRES_PL = { when, already, always, speak, early, study, very, well, ago, yesterday, rain, are, go, past, see, not, teach, twice, give, whereabouts, cook, take, recently, tomorrow, gracefully, do, heavily, turn, constantly, think, before, lately, next, sing, still, today, drink, never }
#      PRES_PERFECT_SG = { has }
#      PRES_PERFECT_PL = { have }
#         PRES_CONT_SG = { is }
#         PRES_CONT_PL = { are }
# PRES_PERFECT_CONT_SG = { has }
# PRES_PERFECT_CONT_PL = { have }
#               FUTURE = { will }
#       FUTURE_PERFECT = { will }
#          FUTURE_CONT = { will }
#  FUTURE_PERFECT_CONT = { will }
#           PRONOUN_SG = { he, her, she, his, i, it, him, my }
#           PRONOUN_PL = { we, you, their, us, they }
#             RELPR_SG = { which }
#             RELPR_PL = { whom }
#           PROPERNOUN = { ishwarya, raj, january, november, joseph, easter, wednesday, switzerland, navvya, canada, ritheesh, paris, may, india, ajitesh, john, america, germany, turkey }
#              NOUN_SG = { picture, school, morning, show, weekend, mountain, cup, airport, sentence, bed, fire, wife, parcel, homework, friend, kabaddi, room, player, brother, car, call, evening, song, baby, neighbourhood, afternoon, night, book, house, football, moment, accident, week, cold, pope, garden, album, pilot, food, teacher, thinking, topper, year, assignment, party, fog, phone, patient, sister, milk, accountant, programming, zoo, basketball, me, tea, husband, outlet, street, movie, letter, building, dad, month, grandfather, weather, mom, airplane }
#              NOUN_PL = { girls, emails, people, goats, specialists, letters, years, films, weeks, books, boys, friends, children, parents, jacksons, roses, peacocks, cows, ages, mountains, times, portraits }
#               DET_SG = { that, an, a, this }
#               DET_PL = { these, many, no, all }
#             DET_BOTH = { the }
#                 CONJ = { and, but, while, because }
#                  ADJ = { last, fun, whole, two, red, nice, sweet, first, delicious, since, new, terrible, critical, hungry, four, every, few, three, severe }
#                  ADV = { recently, tomorrow, when, gracefully, already, always, heavily, constantly, early, lately, before, next, very, well, ago, yesterday, still, today, past, not, twice, whereabouts, never }
#               PREPOS = { from, far, down, around, to, in, of, at, on, by, as, for }
#                V1_SG = { invloves, plays, be, cooks, likes, draws, works, is, climbs, sings, teaches, am, understands, know }
#                V1_PL = { cook, sing, study, do, rain, turn, are, think, go, speak, see, teach, drink, give, take }
#              GERUNDV = { climbing, studying, teaching, dating, feeling, seeing, visiting, meeting, having, ringing, dancing, burning, writing, waiting, looking, opening, taking, raining, enjoying, cleaning, getting, playing, spending, listening, snowing, repairing, suffering, living, going, running }
#                   V2 = { would, married, did, understood, read, was, made, were, caught, started, tired, went, saw, taught, knew, gave, drink, received, flew }
#                   V3 = { watched, given, fed, written, flown, finished, met, done, gone, painted, acted, made, seen }
#
# FOLLOW:
#                   S' = { $ }
#                    S = { when, already, always, early, very, $, well, ago, yesterday, past, not, twice, whereabouts, recently, tomorrow, gracefully, heavily, constantly, before, lately, next, still, today, never }
#                   S1 = { when, already, always, early, very, $, well, ago, yesterday, past, not, twice, whereabouts, recently, tomorrow, gracefully, heavily, constantly, before, lately, next, still, today, never }
#                   NP = { would, and, did, to, am, $, likes, works, yesterday, taught, rain, in, are, teaches, go, see, teach, on, twice, cook, take, because, do, before, went, knew, by, flew, cooks, already, understood, always, speak, early, read, study, from, past, plays, recently, but, sings, have, will, was, tired, sing, around, has, today, never, invloves, when, very, ago, far, is, give, not, married, tomorrow, gracefully, heavily, turn, at, while, were, for, started, saw, still, drink, as, be, well, gave, know, whereabouts, had, received, constantly, think, lately, next, made, caught, draws, down, climbs, understands, of }
#                NP_SG = { would, and, did, to, am, $, likes, works, yesterday, taught, rain, in, teaches, are, go, see, teach, on, twice, cook, take, because, do, before, went, knew, flew, by, cooks, already, understood, always, speak, early, read, study, from, past, plays, recently, but, sings, have, will, was, tired, sing, around, has, today, never, invloves, when, very, ago, far, is, give, not, married, tomorrow, gracefully, heavily, turn, at, while, were, started, for, saw, still, drink, as, be, well, gave, know, whereabouts, had, received, constantly, think, lately, next, made, caught, draws, down, climbs, understands, of }
#               NOM_SG = { would, and, show, did, weekend, airport, to, wife, am, call, song, baby, $, afternoon, likes, night, yesterday, works, football, taught, accident, rain, in, teaches, are, go, see, teach, on, twice, teacher, thinking, cook, take, because, do, sister, before, zoo, basketball, tea, husband, went, street, knew, flew, by, cooks, sentence, already, understood, always, friend, early, kabaddi, read, speak, study, evening, from, house, moment, week, past, album, pilot, plays, recently, but, sings, phone, have, will, was, programming, tired, sing, letter, around, has, today, never, invloves, morning, mountain, when, parcel, homework, brother, car, very, ago, far, book, is, give, not, pope, garden, food, topper, married, tomorrow, gracefully, assignment, heavily, party, fog, turn, at, accountant, while, were, started, for, me, outlet, movie, saw, still, drink, mom, picture, school, bed, cup, fire, room, player, as, be, well, neighbourhood, gave, know, cold, whereabouts, had, received, year, patient, constantly, think, milk, lately, next, made, caught, draws, building, dad, down, climbs, understands, month, grandfather, weather, airplane, of }
#                NP_PL = { would, and, did, to, am, $, likes, works, yesterday, taught, rain, in, are, go, teaches, see, teach, on, twice, cook, take, because, do, before, went, knew, flew, by, cooks, already, understood, always, speak, early, study, read, from, past, plays, recently, but, sings, have, will, was, tired, sing, around, has, today, never, invloves, when, very, ago, far, is, give, not, married, tomorrow, gracefully, heavily, turn, at, while, were, started, for, saw, still, drink, as, be, well, gave, know, whereabouts, had, received, constantly, think, lately, next, made, caught, draws, down, climbs, understands, of }
#               NOM_PL = { would, and, did, to, specialists, am, $, roses, likes, works, yesterday, taught, rain, in, are, go, teaches, see, teach, on, twice, cook, take, because, do, years, before, went, knew, flew, by, girls, cooks, already, understood, always, weeks, speak, early, study, read, friends, from, cows, past, portraits, plays, recently, but, sings, have, will, was, children, parents, tired, sing, around, has, today, mountains, never, invloves, when, people, letters, boys, very, ago, far, is, give, not, married, tomorrow, gracefully, heavily, goats, turn, books, at, while, were, started, for, jacksons, peacocks, saw, still, drink, emails, films, as, be, well, gave, know, times, whereabouts, had, received, constantly, think, lately, next, made, caught, draws, down, climbs, understands, ages, of }
#                   PP = { would, and, did, to, am, $, likes, works, yesterday, taught, rain, in, are, teaches, go, see, teach, on, twice, cook, take, because, do, before, went, knew, by, flew, cooks, already, understood, always, speak, early, read, study, from, past, plays, recently, but, sings, have, will, was, tired, sing, around, has, today, never, invloves, when, very, ago, far, is, give, not, married, tomorrow, gracefully, heavily, turn, at, while, were, for, started, saw, still, drink, as, be, well, gave, know, whereabouts, had, received, constantly, think, lately, next, made, caught, draws, down, climbs, understands, of }
#                 PAST = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#         PAST_PERFECT = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#         PAST_CONT_SG = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#         PAST_CONT_PL = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#    PAST_PERFECT_CONT = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#              PRES_SG = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#              PRES_PL = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
#      PRES_PERFECT_SG = { she, weekend, airport, to, specialists, this, song, accident, in, on, twice, thinking, zoo, since, ritheesh, tea, husband, critical, that, my, by, girls, ishwarya, weeks, early, kabaddi, evening, sweet, he, canada, cows, their, house, moment, week, past, many, portraits, america, phone, red, parents, these, navvya, today, john, never, mountain, when, people, parcel, car, boys, delicious, ago, far, book, may, ajitesh, you, pope, garden, no, heavily, party, fog, goats, at, books, jacksons, peacocks, outlet, movie, i, picture, school, fire, emails, room, player, nice, wednesday, three, whereabouts, germany, times, year, patient, lately, november, next, down, it, weather, airplane, show, an, wife, easter, call, baby, roses, afternoon, night, yesterday, football, hungry, teacher, us, sister, years, before, her, basketball, street, india, they, the, sentence, already, whole, always, friend, friends, all, from, first, album, pilot, turkey, recently, joseph, children, programming, his, letter, around, every, mountains, him, fun, morning, homework, letters, brother, very, a, we, not, food, topper, tomorrow, gracefully, assignment, raj, accountant, for, me, terrible, still, mom, few, last, bed, cup, two, films, as, well, neighbourhood, new, paris, four, cold, january, constantly, milk, switzerland, building, dad, ages, month, grandfather, severe, of }
# ...
# |         437          |                      |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |                      |          r78         |          r78         |          r78         |                      |                      |                      |                      |          r78         |                      |          r78         |                      |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |                      |          r78         |          r78         |                      |                      |          r78         |                      |          r78         |          r78         |          r78         |                      |                      |                      |                      |                      |                      |                      |          r78         |          r78         |                      |                      |          r78         |          r78         |                      |                      |                      |          r78         |                      |          r78         |          r78         |          r78         |                      |                      |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |          r78         |          r78         |          r78         |                      |                      |          r78         |          r78         |          r78         |          r78         |          r78         |                      |          r78         |          r78         |          r78         |          r78         |          r78         |                      |                      |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |                      |          r78         |                      |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |                      |                      |                      |                      |          r78         |                      |                      |                      |                      |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |                      |          r78         |                      |          r78         |                      |          r78         |                      |          r78         |                      |          r78         |                      |          r78         |          r78         |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |          r78         |                      |                      |          r78         |          r78         |          r78         |                      |          r78         |          r78         |                     ...
# |         438          |                      |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |          r90         |          r90         |                      |                      |                      |                      |          r90         |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |          r90         |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |                      |                      |                      |                      |                      |                      |                      |          r90         |          r90         |                      |                      |          r90         |          r90         |                      |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |                      |                      |          r90         |                      |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |          r90         |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                     ...
# +----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-------------------- ...

# %% [markdown]
# ## Module 4 - Evaluation of Grammar Correctness
#
# Input : SLR(1) Parsing table, input sentences
#
# Output : Analysis report of the input
#
#
# -> Stack immplementation of input sentence
#
# -> Semantic analysis using NLP
#
# -> Genration of report

# %%
# Stack implementaion of input strings

def LR_parser(slr, w):
  isAccepted = False
  buffer = [x for x in w]
  buffer.append('$')
  pointer = 0
  a = buffer[pointer]
  stack = ['0']
  symbols = ['']
  results = {'step': [''], 'stack': ['STACK'] + stack, 'symbols': ['SYMBOLS'] + symbols, 'input': ['INPUT'], 'action': ['ACTION']}

  step = 0
  while True:
    s = int(stack[-1])
    step += 1
    results['step'].append(f'({step})')
    results['input'].append(' '.join(buffer[pointer:]))

    if a not in slr.parse_table[s]:
      results['action'].append(f'ERROR: unrecognized symbol {a}')
      isAccepted = False
      break

    elif not slr.parse_table[s][a]:
      results['action'].append('ERROR: input cannot be parsed by given grammar')
      isAccepted = False
      break

    elif '/' in slr.parse_table[s][a]:
      action = 'reduce' if slr.parse_table[s][a].count('r') > 1 else 'shift'
      results['action'].append(f'ERROR: {action}-reduce conflict at state {s}, symbol {a}')
      isAccepted = False
      break

    elif slr.parse_table[s][a].startswith('s'):
      results['action'].append('shift')
      stack.append(slr.parse_table[s][a][1:])
      symbols.append(a)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))
      pointer += 1
      a = buffer[pointer]

    elif slr.parse_table[s][a].startswith('r'):
      head, body = slr.G_indexed[int(slr.parse_table[s][a][1:])]
      results['action'].append(f'reduce by {head} -> {" ".join(body)}')

      if body != ('^',):
        stack = stack[:-len(body)]
        symbols = symbols[:-len(body)]

      stack.append(str(slr.parse_table[int(stack[-1])][head]))
      symbols.append(head)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))

    elif slr.parse_table[s][a] == 'acc':
      results['action'].append('accept')
      isAccepted = True
      break

  # Printing results
  def print_line():
    print(f'{"".join(["+" + ("-" * (max_len + 2)) for max_len in max_lens.values()])}+')

  max_lens = {key: max(len(value) for value in results[key]) for key in results}
  justs = {'step': '>', 'stack': '', 'symbols': '', 'input': '>', 'action': ''}

  print_line()
  print(''.join([f'| {history[0]:^{max_len}} ' for history, max_len in zip(results.values(), max_lens.values())]) + '|')
  print_line()
  for i, step in enumerate(results['step'][:-1], 1):
    print(''.join([f'| {history[i]:{just}{max_len}} ' for history, just, max_len in zip(results.values(), justs.values(), max_lens.values())]) + '|')

  print_line()

  return isAccepted

# %%
incorrectSentenceCount = 0
incorrectSentenceResult = []
for input_text in correctedWordsArray :
  isAccepted = LR_parser(slr, input_text)
  # Performing semantic analysis  using nlp for grammar corrections
  if(not isAccepted) :
    print("Correction : ")
    correction = GingerIt().parse(" ".join(input_text))['result']
    print(correction)
    incorrectSentenceCount += 1
    incorrectSentenceResult.append("Incorrect sentence : {}\nCorrection : {}\n\n".format(" ".join(input_text), correction))
# Out:
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                  |                     ACTION                     |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# | (1) | 0         |             | she were writing a letter to ishwarya $ | shift                                          |
# | (2) | 0 1       |  she        |     were writing a letter to ishwarya $ | reduce by PRONOUN_SG -> she                    |
# | (3) | 0 52      |  PRONOUN_SG |     were writing a letter to ishwarya $ | reduce by NP_SG -> PRONOUN_SG                  |
# | (4) | 0 114     |  NP_SG      |     were writing a letter to ishwarya $ | shift                                          |
# | (5) | 0 114 280 |  NP_SG were |          writing a letter to ishwarya $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# Correction :
# she was writing a letter to ishwarya
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |      |     STACK     |       SYMBOLS       |           INPUT           |                ACTION                |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |  (1) | 0             |                     | my teacher teaches well $ | shift                                |
# |  (2) | 0 20          |  my                 |    teacher teaches well $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 52          |  PRONOUN_SG         |    teacher teaches well $ | shift                                |
# |  (4) | 0 52 109      |  PRONOUN_SG teacher |            teaches well $ | reduce by NOUN_SG -> teacher         |
# |  (5) | 0 52 57       |  PRONOUN_SG NOUN_SG |            teaches well $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 52 248      |  PRONOUN_SG NOM_SG  |            teaches well $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 114         |  NP_SG              |            teaches well $ | shift                                |
# |  (8) | 0 114 274     |  NP_SG teaches      |                    well $ | reduce by V1_SG -> teaches           |
# |  (9) | 0 114 276     |  NP_SG V1_SG        |                    well $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 114 268     |  NP_SG PRES_SG      |                    well $ | shift                                |
# | (11) | 0 114 268 171 |  NP_SG PRES_SG well |                         $ | reduce by ADV -> well                |
# | (12) | 0 114 268 320 |  NP_SG PRES_SG ADV  |                         $ | reduce by S1 -> ADV                  |
# | (13) | 0 114 268 400 |  NP_SG PRES_SG S1   |                         $ | reduce by S -> NP_SG PRES_SG S1      |
# | (14) | 0 8           |  S                  |                         $ | accept                               |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |      |       STACK       |          SYMBOLS           |        INPUT         |            ACTION             |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |  (1) | 0                 |                            | she went to school $ | shift                         |
# |  (2) | 0 1               |  she                       |     went to school $ | reduce by PRONOUN_SG -> she   |
# |  (3) | 0 52              |  PRONOUN_SG                |     went to school $ | reduce by NP_SG -> PRONOUN_SG |
# |  (4) | 0 114             |  NP_SG                     |     went to school $ | shift                         |
# |  (5) | 0 114 230         |  NP_SG went                |          to school $ | reduce by V2 -> went          |
# |  (6) | 0 114 231         |  NP_SG V2                  |          to school $ | reduce by PAST -> V2          |
# |  (7) | 0 114 285         |  NP_SG PAST                |          to school $ | shift                         |
# |  (8) | 0 114 285 295     |  NP_SG PAST to             |             school $ | reduce by PREPOS -> to        |
# |  (9) | 0 114 285 299     |  NP_SG PAST PREPOS         |             school $ | shift                         |
# | (10) | 0 114 285 299 76  |  NP_SG PAST PREPOS school  |                    $ | reduce by NOUN_SG -> school   |
# | (11) | 0 114 285 299 57  |  NP_SG PAST PREPOS NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG   |
# | (12) | 0 114 285 299 93  |  NP_SG PAST PREPOS NOM_SG  |                    $ | reduce by NP_SG -> NOM_SG     |
# | (13) | 0 114 285 299 410 |  NP_SG PAST PREPOS NP_SG   |                    $ | reduce by PP -> PREPOS NP_SG  |
# | (14) | 0 114 285 306     |  NP_SG PAST PP             |                    $ | reduce by NP -> PP            |
# | (15) | 0 114 285 318     |  NP_SG PAST NP             |                    $ | reduce by S1 -> NP            |
# | (16) | 0 114 285 408     |  NP_SG PAST S1             |                    $ | reduce by S -> NP_SG PAST S1  |
# | (17) | 0 8               |  S                         |                    $ | accept                        |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |           INPUT            |                     ACTION                     |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# | (1) | 0         |             | raj is climbs a mountain $ | shift                                          |
# | (2) | 0 157     |  raj        |     is climbs a mountain $ | reduce by PROPERNOUN -> raj                    |
# | (3) | 0 168     |  PROPERNOUN |     is climbs a mountain $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 114     |  NP_SG      |     is climbs a mountain $ | shift                                          |
# | (5) | 0 114 266 |  NP_SG is   |        climbs a mountain $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# Correction :
# raj climbs a mountain
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |      |     STACK     |         SYMBOLS         |           INPUT           |             ACTION              |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |  (1) | 0             |                         | raj plays football well $ | shift                           |
# |  (2) | 0 157         |  raj                    |     plays football well $ | reduce by PROPERNOUN -> raj     |
# |  (3) | 0 168         |  PROPERNOUN             |     plays football well $ | reduce by NP_SG -> PROPERNOUN   |
# |  (4) | 0 114         |  NP_SG                  |     plays football well $ | shift                           |
# |  (5) | 0 114 259     |  NP_SG plays            |           football well $ | reduce by V1_SG -> plays        |
# |  (6) | 0 114 276     |  NP_SG V1_SG            |           football well $ | reduce by PRES_SG -> V1_SG      |
# |  (7) | 0 114 268     |  NP_SG PRES_SG          |           football well $ | shift                           |
# |  (8) | 0 114 268 107 |  NP_SG PRES_SG football |                    well $ | reduce by NOUN_SG -> football   |
# |  (9) | 0 114 268 57  |  NP_SG PRES_SG NOUN_SG  |                    well $ | reduce by NOM_SG -> NOUN_SG     |
# | (10) | 0 114 268 93  |  NP_SG PRES_SG NOM_SG   |                    well $ | reduce by NP_SG -> NOM_SG       |
# | (11) | 0 114 268 305 |  NP_SG PRES_SG NP_SG    |                    well $ | reduce by NP -> NP_SG           |
# | (12) | 0 114 268 318 |  NP_SG PRES_SG NP       |                    well $ | reduce by S1 -> NP              |
# | (13) | 0 114 268 400 |  NP_SG PRES_SG S1       |                    well $ | reduce by S -> NP_SG PRES_SG S1 |
# | (14) | 0 8           |  S                      |                    well $ | shift                           |
# | (15) | 0 8 171       |  S well                 |                         $ | reduce by ADV -> well           |
# | (16) | 0 8 191       |  S ADV                  |                         $ | reduce by S -> S ADV            |
# | (17) | 0 8           |  S                      |                         $ | accept                          |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# +-----+-------+----------+---------------------------+------------------------------------------------+
# |     | STACK | SYMBOLS  |           INPUT           |                     ACTION                     |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# | (1) | 0     |          | mom cook delicious food $ | shift                                          |
# | (2) | 0 163 |  mom     |     cook delicious food $ | reduce by NOUN_SG -> mom                       |
# | (3) | 0 57  |  NOUN_SG |     cook delicious food $ | reduce by NOM_SG -> NOUN_SG                    |
# | (4) | 0 93  |  NOM_SG  |     cook delicious food $ | reduce by NP_SG -> NOM_SG                      |
# | (5) | 0 114 |  NP_SG   |     cook delicious food $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# Correction :
# mom cooks delicious food
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# |      |      STACK      |            SYMBOLS            |        INPUT         |              ACTION              |
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# |  (1) | 0               |                               | navvya is a topper $ | shift                            |
# |  (2) | 0 43            |  navvya                       |        is a topper $ | reduce by PROPERNOUN -> navvya   |
# |  (3) | 0 168           |  PROPERNOUN                   |        is a topper $ | reduce by NP_SG -> PROPERNOUN    |
# |  (4) | 0 114           |  NP_SG                        |        is a topper $ | shift                            |
# |  (5) | 0 114 266       |  NP_SG is                     |           a topper $ | reduce by V1_SG -> is            |
# |  (6) | 0 114 276       |  NP_SG V1_SG                  |           a topper $ | reduce by PRES_SG -> V1_SG       |
# |  (7) | 0 114 268       |  NP_SG PRES_SG                |           a topper $ | shift                            |
# |  (8) | 0 114 268 147   |  NP_SG PRES_SG a              |             topper $ | reduce by DET_SG -> a            |
# |  (9) | 0 114 268 5     |  NP_SG PRES_SG DET_SG         |             topper $ | shift                            |
# | (10) | 0 114 268 5 153 |  NP_SG PRES_SG DET_SG topper  |                    $ | reduce by NOUN_SG -> topper      |
# | (11) | 0 114 268 5 57  |  NP_SG PRES_SG DET_SG NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG      |
# | (12) | 0 114 268 5 189 |  NP_SG PRES_SG DET_SG NOM_SG  |                    $ | reduce by NP_SG -> DET_SG NOM_SG |
# | (13) | 0 114 268 305   |  NP_SG PRES_SG NP_SG          |                    $ | reduce by NP -> NP_SG            |
# | (14) | 0 114 268 318   |  NP_SG PRES_SG NP             |                    $ | reduce by S1 -> NP               |
# | (15) | 0 114 268 400   |  NP_SG PRES_SG S1             |                    $ | reduce by S -> NP_SG PRES_SG S1  |
# | (16) | 0 8             |  S                            |                    $ | accept                           |
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# |      |        STACK        |               SYMBOLS                |             INPUT              |               ACTION               |
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# |  (1) | 0                   |                                      | ishwarya is a kabaddi player $ | shift                              |
# |  (2) | 0 22                |  ishwarya                            |          is a kabaddi player $ | reduce by PROPERNOUN -> ishwarya   |
# |  (3) | 0 168               |  PROPERNOUN                          |          is a kabaddi player $ | reduce by NP_SG -> PROPERNOUN      |
# |  (4) | 0 114               |  NP_SG                               |          is a kabaddi player $ | shift                              |
# |  (5) | 0 114 266           |  NP_SG is                            |             a kabaddi player $ | reduce by V1_SG -> is              |
# |  (6) | 0 114 276           |  NP_SG V1_SG                         |             a kabaddi player $ | reduce by PRES_SG -> V1_SG         |
# |  (7) | 0 114 268           |  NP_SG PRES_SG                       |             a kabaddi player $ | shift                              |
# |  (8) | 0 114 268 147       |  NP_SG PRES_SG a                     |               kabaddi player $ | reduce by DET_SG -> a              |
# |  (9) | 0 114 268 5         |  NP_SG PRES_SG DET_SG                |               kabaddi player $ | shift                              |
# | (10) | 0 114 268 5 24      |  NP_SG PRES_SG DET_SG kabaddi        |                       player $ | reduce by NOUN_SG -> kabaddi       |
# | (11) | 0 114 268 5 57      |  NP_SG PRES_SG DET_SG NOUN_SG        |                       player $ | reduce by NOM_SG -> NOUN_SG        |
# | (12) | 0 114 268 5 189     |  NP_SG PRES_SG DET_SG NOM_SG         |                       player $ | shift                              |
# | (13) | 0 114 268 5 189 80  |  NP_SG PRES_SG DET_SG NOM_SG player  |                              $ | reduce by NOUN_SG -> player        |
# | (14) | 0 114 268 5 189 251 |  NP_SG PRES_SG DET_SG NOM_SG NOUN_SG |                              $ | reduce by NOM_SG -> NOM_SG NOUN_SG |
# | (15) | 0 114 268 5 189     |  NP_SG PRES_SG DET_SG NOM_SG         |                              $ | reduce by NP_SG -> DET_SG NOM_SG   |
# | (16) | 0 114 268 305       |  NP_SG PRES_SG NP_SG                 |                              $ | reduce by NP -> NP_SG              |
# | (17) | 0 114 268 318       |  NP_SG PRES_SG NP                    |                              $ | reduce by S1 -> NP                 |
# | (18) | 0 114 268 400       |  NP_SG PRES_SG S1                    |                              $ | reduce by S -> NP_SG PRES_SG S1    |
# | (19) | 0 8                 |  S                                   |                              $ | accept                             |
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                   |                     ACTION                     |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# | (1) | 0         |             | ishwarya will sings a song in the show $ | shift                                          |
# | (2) | 0 22      |  ishwarya   |          will sings a song in the show $ | reduce by PROPERNOUN -> ishwarya               |
# | (3) | 0 168     |  PROPERNOUN |          will sings a song in the show $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 114     |  NP_SG      |          will sings a song in the show $ | shift                                          |
# | (5) | 0 114 206 |  NP_SG will |               sings a song in the show $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# Correction :
# Ishwarya will sing a song in the show
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# |     |  STACK   |     SYMBOLS     |             INPUT             |                     ACTION                     |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# | (1) | 0        |                 | these people is from canada $ | shift                                          |
# | (2) | 0 42     |  these          |       people is from canada $ | reduce by DET_PL -> these                      |
# | (3) | 0 83     |  DET_PL         |       people is from canada $ | shift                                          |
# | (4) | 0 83 50  |  DET_PL people  |              is from canada $ | reduce by NOUN_PL -> people                    |
# | (5) | 0 83 47  |  DET_PL NOUN_PL |              is from canada $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 83 250 |  DET_PL NOM_PL  |              is from canada $ | reduce by NP_PL -> DET_PL NOM_PL               |
# | (7) | 0 12     |  NP_PL          |              is from canada $ | ERROR: input cannot be parsed by given grammar |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# Correction :
# these people are from Canada

# %%
outputLines.append("Incorrect sentences count : {}\n\n".format(incorrectSentenceCount))
outputLines.append("---------------------------------------------\n\n")
for result in incorrectSentenceResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# WRITING RESULT TO THE OUTPUT FILE

outputFile = open("output.txt", "w")
for line in outputLines:
  outputFile.write(line)
outputFile.close()
